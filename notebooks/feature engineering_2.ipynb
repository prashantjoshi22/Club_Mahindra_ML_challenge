# %%
import pandas as pd
import lightgbm
from sklearn.preprocessing import CategoricalEncoder,OrdinalEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from bayes_opt import BayesianOptimization
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import numpy as np
import datetime
from tqdm import tqdm_notebook as tqdm
import category_encoders as ce

# %%
train = pd.read_csv("./train_5CLrC8b/train.csv")
test = pd.read_csv("./test.csv")
sample_submission = pd.read_csv("./sample_submission.csv")

# %%
concated = pd.concat([train,test],ignore_index=True)
# Out:
# /home/prashant/miniconda2/envs/p3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
concated['booking_date'] = pd.to_datetime(concated['booking_date'],dayfirst=True)
concated['checkin_date'] = pd.to_datetime(concated['checkin_date'],dayfirst=True)
concated['checkout_date'] = pd.to_datetime(concated['checkout_date'],dayfirst=True)

# %%
concated['booking_month'] = concated['booking_date'].apply(lambda x:x.month)
concated['booking_year'] = concated['booking_date'].apply(lambda x:x.year)
concated['booking_day'] = concated['booking_date'].apply(lambda x:x.day)

concated['checkin_month'] = concated['checkin_date'].apply(lambda x:x.month)
concated['checkin_year'] = concated['checkin_date'].apply(lambda x:x.year)
concated['checkin_day'] = concated['checkin_date'].apply(lambda x:x.day)

concated['checkout_month'] = concated['checkout_date'].apply(lambda x:x.month)
concated['checkout_year'] = concated['checkout_date'].apply(lambda x:x.year)
concated['checkout_day'] = concated['checkout_date'].apply(lambda x:x.day)

# %%
concated['booking_dayofweek'] = concated['booking_date'].apply(lambda x:x.dayofweek)

concated['checkin_dayofweek'] = concated['checkin_date'].apply(lambda x:x.dayofweek)

concated['checkout_dayofweek'] = concated['checkout_date'].apply(lambda x:x.dayofweek)

# %%
concated['season_holidayed_code_is_na'] = concated.season_holidayed_code.apply(
    lambda x: 1 if pd.isna(x) else 0)
concated['state_code_residence_is_na'] = concated.state_code_residence.apply(
    lambda x: 1 if pd.isna(x) else 0)
concated['season_holidayed_code'] = concated.season_holidayed_code.apply(
    lambda x: 0 if pd.isna(x) else x)
concated['state_code_residence'] = concated.state_code_residence.apply(
    lambda x: 0 if pd.isna(x) else x)

# %%
concated['actual_days_booked'] = concated.apply(
    lambda x: (x['checkout_date'] - x['checkin_date']).days, axis=1)

# %%
concated['n_rooms_booked'] = concated.apply(
    lambda x: x['roomnights'] / x['actual_days_booked'], axis=1)

# %%
concated['person_per_room'] = concated.apply(
    lambda x: (x['numberofadults'] + x['numberofchildren']) / x['n_rooms_booked'] if x['n_rooms_booked'] else 0,
    axis=1)

# %%
def count_weekend(row):
    checkin_date = row['checkin_date']
    actual_days_booked = row['actual_days_booked']
    stayed_in_weekend = 0
    for i in range(actual_days_booked):
        new_day = (checkin_date + datetime.timedelta(days=i)).day_name()
        if new_day == "Saturday" or new_day == "Friday" or new_day == "Sunday":
            stayed_in_weekend += 1
    return stayed_in_weekend

# %%
concated['n_weekend_days'] = concated.apply(count_weekend,axis=1)

# %%
encoder = OrdinalEncoder(dtype=np.int32, )
concated[[
    'member_age_buckets', 'cluster_code', 'reservationstatusid_code',
    'resort_id'
]] = encoder.fit_transform(concated[[
    'member_age_buckets', 'cluster_code', 'reservationstatusid_code',
    'resort_id'
]])

# %%
concat_sorted = concated.sort_values('booking_date')
concat_sorted_grouped = concat_sorted.groupby('memberid')
n_previous_bookings = [0]*len(concated)
days_between_previous_bookings = [0]*len(concated)
for memberid,grouped_df in tqdm(concat_sorted_grouped):
    count = 0
    previous_booking_date = 0
    for ind,data in enumerate(grouped_df.iterrows()):
        index,row = data
        n_previous_bookings[index] = count
        count += 1
        
        if ind == 0:
            days_between_previous_bookings[index] = 0
        else:
            days_between_previous_bookings[index] = (row['booking_date'] - previous_booking_date).days
        previous_booking_date = row['booking_date']
concated['n_previous_bookings'] = n_previous_bookings
concated['days_between_previous_bookings'] = days_between_previous_bookings
# Out:
# HBox(children=(IntProgress(value=0, max=144823), HTML(value='')))

# %%
seasons = {
    3: 1,
    4: 1,
    5: 1,
    6: 2,
    7: 2,
    8: 2,
    9: 3,
    10: 3,
    11: 3,
    12: 4,
    1: 4,
    2: 4
}
def get_season_india(row):
    checking_month = row['checkin_month']
    return seasons[checking_month]

# %%
concated['child2person_ratio'] = concated.apply(
    lambda x: x['numberofchildren'] / x['numberofadults'] if x['numberofadults'] else 0,
    axis=1)
concated['seasons'] = concated.apply(get_season_india, axis=1)

# %%
concated['travelline_in_same_state'] = concated.apply(
    lambda x: 1 if x['state_code_residence'] == x['state_code_resort'] else 0,
    axis=1)

# %%
def count_weekday(row):
    checkin_date = row['checkin_date']
    actual_days_booked = row['actual_days_booked']
    stayed_in_weekend = 0
    stayed_in_weekday = 0
    for i in range(actual_days_booked):
        new_day = (checkin_date + datetime.timedelta(days=i)).day_name()
        if new_day == "Saturday" or new_day == "Friday" or new_day == "Sunday":
            stayed_in_weekend += 1
        else:
            stayed_in_weekday += 1
    return stayed_in_weekday

# %%
concated['stayed_in_weekday'] = concated.apply(count_weekday,axis=1)

# %%
concated['booking_advance_days'] = concated.apply(
    lambda x: (x['checkin_date'] - x['booking_date']).days, axis=1)

# %%
concat_sorted = concated.sort_values('checkin_date')
concat_sorted_grouped = concat_sorted.groupby('memberid')
days_between_previous_checkins = [0]*len(concated)
for memberid,grouped_df in tqdm(concat_sorted_grouped):
    previous_checking_date = 0
    for ind,data in enumerate(grouped_df.iterrows()):
        index,row = data
        if ind == 0:
            days_between_previous_checkins[index] = 0
        else:
            days_between_previous_checkins[index] = (row['checkin_date'] - previous_checking_date).days
        previous_checking_date = row['checkin_date']
concated['days_between_previous_checkins'] = days_between_previous_checkins
# Out:
# HBox(children=(IntProgress(value=0, max=144823), HTML(value='')))

# %%
concat_sorted = concated.sort_values('checkin_date')
concat_sorted_grouped = concat_sorted.groupby(['memberid','checkin_year'])
yearly_visit_number = [0]*len(concated)
total_yearly_visits = [0]*len(concated)
for memberid,grouped_df in tqdm(concat_sorted_grouped):
    num = 1
    tot = len(grouped_df)
    for ind,data in enumerate(grouped_df.iterrows()):
        index,row = data
        yearly_visit_number[index] = num
        total_yearly_visits[index] = tot
        num += 1
concated['yearly_visit_number'] = yearly_visit_number
concated['total_yearly_visits'] = total_yearly_visits
# Out:
# HBox(children=(IntProgress(value=0, max=309756), HTML(value='')))

# %%
concat_sorted_grouped = concated.groupby(['memberid'])
memberid_total_visits = [0]*len(concated)
for memberid,grouped_df in tqdm(concat_sorted_grouped):
    tot = len(grouped_df)
    for ind,data in enumerate(grouped_df.iterrows()):
        index,row = data
        memberid_total_visits[index] = tot
concated['memberid_total_visits'] = memberid_total_visits
# Out:
# HBox(children=(IntProgress(value=0, max=144823), HTML(value='')))

# %%
more_features =list(pd.read_csv('/home/prashant/Downloads/JJ.csv',header = None)[0])

# %%
len(more_features)
# Out:
# 488189

# %%
#concated['more_fet'] = more_features

# %%
concated.shape

# %%
x = pd.DataFrame(concated.groupby('resort_id').count()['total_pax'])
y = x.to_dict()['total_pax']

uu = []
for i in concated['resort_id']:
    uu.append(y[i])

# %%
concated['count'] = uu

# %%
# # concated.to_csv("./concat_train_test_feat_engg.csv",index=False)
# concated = pd.read_csv("./concat_train_test_feat_engg.csv")
# train = pd.read_csv("./train_5CLrC8b/train.csv")
# test = pd.read_csv("./test.csv")
# sample_submission = pd.read_csv("./sample_submission.csv")
# concated['booking_date'] = pd.to_datetime(
#     concated['booking_date'], dayfirst=True)
# concated['checkin_date'] = pd.to_datetime(
#     concated['checkin_date'], dayfirst=True)
# concated['checkout_date'] = pd.to_datetime(
#     concated['checkout_date'], dayfirst=True)

# %%
concated.T

# %%
# concated.drop(['reservation_id','booking_date','checkin_date','checkout_date','memberid'],axis=1,inplace=True)
cat_columns = [
    'booking_type_code', 'channel_code', 'main_product_code',
    'persontravellingid', 'member_age_buckets', 'cluster_code',
    'reservationstatusid_code', 'resort_region_code', 'resort_type_code',
    'room_type_booked_code', 'season_holidayed_code', 'seasons', "resort_id",
    "state_code_residence", "state_code_resort", 'season_holidayed_code_is_na',
    'state_code_residence_is_na', 'travelline_in_same_state'
]
to_drop_columns = [
    'amount_spent_per_room_night_scaled',
    'reservation_id',
    'booking_date',
    'checkin_date',
    'checkout_date',
    'memberid',
    'resort_type_code',
    'cluster_code',
    'reservationstatusid_code',
    'state_code_resort',
    'resort_region_code',
    
]

cat_columns = list(set(cat_columns) - set(to_drop_columns))
# for c in cat_columns:
#     print(c,":",len(concated[c].unique()),"\n")

# encoder = ce.polynomial.PolynomialEncoder(cols=cat_columns)

# concated = encoder.fit_transform(concated)

# %%
params= {'bagging_fraction': 0.8506230273762951,
  'bagging_freq': int(11.997717202080683),
  'cat_l2': 17.76603440180926,
  'cat_smooth': 90.01338713539889,
  'drop_rate': 0.828471324834864,
  'feature_fraction': 0.5396781843922561,
  'lambda_l1': 5.11481807918487,
  'lambda_l2': 9.972192609474396,
  'max_cat_threshold': int(9834.145546034471),
  'max_cat_to_onehot': int(397.4975773409506),
  'max_delta_step': 5.509600723103176,
  'max_depth': int(9818.20211661785),
  'max_drop': int(30.8804918777279),
  'min_data_in_leaf': int(276.1481648277242),
  'min_data_per_group': int(3945.772360706398),
  'min_gain_to_split': 5.038274756279193,
  'min_sum_hessian_in_leaf': 0.9125303541207858,
  'num_leaves': int(9369.57052885872),
  'other_rate': 0.0806926301303258,
  'skip_drop': 0.7679739421390375,
    'objective': 'regression',
         'metric': 'rmse',
  'top_rate': 0.922033189148117}

# %%
# concated.to_csv("./concat_train_test_feat_engg.dropped.csv",index=False)
# concated = pd.read_csv("./concat_train_test_feat_engg.dropped.csv")
# sample_submission = pd.read_csv("./sample_submission.csv")
# train = pd.read_csv("./train_5CLrC8b/train.csv")
# test = pd.read_csv("./test.csv")
# sample_submission = pd.read_csv("./sample_submission.csv")

# %%
train = concated[:len(train)]
test = concated[-len(test):]

# %%
all_predictions = []
# all_training_predictions = []
X = train.drop(to_drop_columns, axis=1)
Y = train['amount_spent_per_room_night_scaled']
import lightgbm as lgb

for i in range(10):
    print(i)
    trainX, testX, trainY, testY = train_test_split(X, Y, test_size=0.15)
    d_train = lgb.Dataset(trainX, label=trainY)
    d_test = lgb.Dataset(testX,testY)
    lgb_model = lgb.train(params, d_train,1000,valid_sets=(d_test),
        early_stopping_rounds=100,
        categorical_feature=cat_columns)
    #lgb_model = lightgbm.LGBMRegressor(n_estimators=1000)
#     lgb.fit(
#         trainX,
#         trainY,
#         eval_set=(testX, testY),
#         early_stopping_rounds=100,
#         categorical_feature=cat_columns,
#     )
    #     predictions = lgb_model.predict(X)
    #     all_training_predictions.append(predictions)
    predictions = lgb_model.predict(test.drop(to_drop_columns, axis=1))
    all_predictions.append(predictions)
# Out:
# 0
# /home/prashant/miniconda2/envs/p3/lib/python3.6/site-packages/lightgbm/basic.py:1209: UserWarning: categorical_feature in Dataset is overridden.
# New categorical_feature is ['booking_type_code', 'channel_code', 'main_product_code', 'member_age_buckets', 'persontravellingid', 'resort_id', 'room_type_booked_code', 'season_holidayed_code', 'season_holidayed_code_is_na', 'seasons', 'state_code_residence', 'state_code_residence_is_na', 'travelline_in_same_state']
#   'New categorical_feature is {}'.format(sorted(list(categorical_feature))))
# /home/prashant/miniconda2/envs/p3/lib/python3.6/site-packages/lightgbm/basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	valid_0's rmse: 1.07043
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.05896
# [3]	valid_0's rmse: 1.04758
# [4]	valid_0's rmse: 1.03793
# [5]	valid_0's rmse: 1.02912
# [6]	valid_0's rmse: 1.02237
# [7]	valid_0's rmse: 1.01667
# [8]	valid_0's rmse: 1.01178
# [9]	valid_0's rmse: 1.0081
# [10]	valid_0's rmse: 1.0045
# [11]	valid_0's rmse: 1.00107
# [12]	valid_0's rmse: 0.99822
# [13]	valid_0's rmse: 0.995319
# [14]	valid_0's rmse: 0.992853
# [15]	valid_0's rmse: 0.990593
# [16]	valid_0's rmse: 0.988764
# [17]	valid_0's rmse: 0.98736
# [18]	valid_0's rmse: 0.985609
# [19]	valid_0's rmse: 0.984232
# [20]	valid_0's rmse: 0.982954
# [21]	valid_0's rmse: 0.981715
# [22]	valid_0's rmse: 0.980714
# [23]	valid_0's rmse: 0.979873
# [24]	valid_0's rmse: 0.978891
# [25]	valid_0's rmse: 0.977985
# [26]	valid_0's rmse: 0.977446
# [27]	valid_0's rmse: 0.976873
# [28]	valid_0's rmse: 0.976286
# [29]	valid_0's rmse: 0.975659
# [30]	valid_0's rmse: 0.975131
# [31]	valid_0's rmse: 0.974481
# [32]	valid_0's rmse: 0.974112
# [33]	valid_0's rmse: 0.973761
# [34]	valid_0's rmse: 0.973445
# [35]	valid_0's rmse: 0.973199
# [36]	valid_0's rmse: 0.972935
# [37]	valid_0's rmse: 0.972755
# [38]	valid_0's rmse: 0.972436
# [39]	valid_0's rmse: 0.972303
# [40]	valid_0's rmse: 0.972071
# [41]	valid_0's rmse: 0.971632
# [42]	valid_0's rmse: 0.971427
# [43]	valid_0's rmse: 0.971124
# [44]	valid_0's rmse: 0.970971
# [45]	valid_0's rmse: 0.970803
# [46]	valid_0's rmse: 0.970649
# [47]	valid_0's rmse: 0.970409
# [48]	valid_0's rmse: 0.970249
# [49]	valid_0's rmse: 0.970025
# [50]	valid_0's rmse: 0.96989
# [51]	valid_0's rmse: 0.96975
# [52]	valid_0's rmse: 0.96963
# [53]	valid_0's rmse: 0.969512
# [54]	valid_0's rmse: 0.969382
# [55]	valid_0's rmse: 0.96934
# [56]	valid_0's rmse: 0.969223
# [57]	valid_0's rmse: 0.969149
# [58]	valid_0's rmse: 0.968999
# [59]	valid_0's rmse: 0.968909
# [60]	valid_0's rmse: 0.96884
# [61]	valid_0's rmse: 0.968752
# [62]	valid_0's rmse: 0.968725
# [63]	valid_0's rmse: 0.968673
# [64]	valid_0's rmse: 0.968628
# [65]	valid_0's rmse: 0.968592
# [66]	valid_0's rmse: 0.968548
# [67]	valid_0's rmse: 0.968469
# [68]	valid_0's rmse: 0.968378
# [69]	valid_0's rmse: 0.968342
# [70]	valid_0's rmse: 0.968306
# [71]	valid_0's rmse: 0.968276
# [72]	valid_0's rmse: 0.968266
# [73]	valid_0's rmse: 0.968238
# [74]	valid_0's rmse: 0.968129
# [75]	valid_0's rmse: 0.968121
# [76]	valid_0's rmse: 0.968102
# [77]	valid_0's rmse: 0.968074
# [78]	valid_0's rmse: 0.96805
# [79]	valid_0's rmse: 0.968031
# [80]	valid_0's rmse: 0.968009
# [81]	valid_0's rmse: 0.967993
# [82]	valid_0's rmse: 0.967975
# [83]	valid_0's rmse: 0.967918
# [84]	valid_0's rmse: 0.967885
# [85]	valid_0's rmse: 0.967872
# [86]	valid_0's rmse: 0.967866
# [87]	valid_0's rmse: 0.967845
# [88]	valid_0's rmse: 0.967832
# [89]	valid_0's rmse: 0.967809
# [90]	valid_0's rmse: 0.967784
# [91]	valid_0's rmse: 0.967757
# [92]	valid_0's rmse: 0.967752
# [93]	valid_0's rmse: 0.967748
# [94]	valid_0's rmse: 0.967737
# [95]	valid_0's rmse: 0.96773
# [96]	valid_0's rmse: 0.967725
# [97]	valid_0's rmse: 0.967727
# [98]	valid_0's rmse: 0.967713
# [99]	valid_0's rmse: 0.967706
# [100]	valid_0's rmse: 0.967692
# [101]	valid_0's rmse: 0.967684
# [102]	valid_0's rmse: 0.967678
# [103]	valid_0's rmse: 0.967672
# [104]	valid_0's rmse: 0.967672
# [105]	valid_0's rmse: 0.967679
# [106]	valid_0's rmse: 0.967679
# [107]	valid_0's rmse: 0.967679
# [108]	valid_0's rmse: 0.967679
# [109]	valid_0's rmse: 0.967679
# [110]	valid_0's rmse: 0.967679
# [111]	valid_0's rmse: 0.967681
# [112]	valid_0's rmse: 0.967681
# [113]	valid_0's rmse: 0.967681
# [114]	valid_0's rmse: 0.967681
# [115]	valid_0's rmse: 0.967681
# [116]	valid_0's rmse: 0.967681
# [117]	valid_0's rmse: 0.967681
# [118]	valid_0's rmse: 0.967681
# [119]	valid_0's rmse: 0.967681
# [120]	valid_0's rmse: 0.967681
# [121]	valid_0's rmse: 0.967681
# [122]	valid_0's rmse: 0.967681
# [123]	valid_0's rmse: 0.967681
# [124]	valid_0's rmse: 0.967681
# [125]	valid_0's rmse: 0.967681
# [126]	valid_0's rmse: 0.967681
# [127]	valid_0's rmse: 0.967681
# [128]	valid_0's rmse: 0.967681
# [129]	valid_0's rmse: 0.967681
# [130]	valid_0's rmse: 0.967681
# [131]	valid_0's rmse: 0.967681
# [132]	valid_0's rmse: 0.967681
# [133]	valid_0's rmse: 0.967681
# [134]	valid_0's rmse: 0.967681
# [135]	valid_0's rmse: 0.967681
# [136]	valid_0's rmse: 0.967681
# [137]	valid_0's rmse: 0.967681
# [138]	valid_0's rmse: 0.967681
# [139]	valid_0's rmse: 0.967681
# [140]	valid_0's rmse: 0.967681
# [141]	valid_0's rmse: 0.967681
# [142]	valid_0's rmse: 0.967681
# [143]	valid_0's rmse: 0.967681
# [144]	valid_0's rmse: 0.967681
# [145]	valid_0's rmse: 0.967681
# [146]	valid_0's rmse: 0.967681
# [147]	valid_0's rmse: 0.967681
# [148]	valid_0's rmse: 0.967681
# [149]	valid_0's rmse: 0.967681
# [150]	valid_0's rmse: 0.967681
# [151]	valid_0's rmse: 0.967681
# [152]	valid_0's rmse: 0.967681
# [153]	valid_0's rmse: 0.967681
# [154]	valid_0's rmse: 0.967681
# [155]	valid_0's rmse: 0.967681
# [156]	valid_0's rmse: 0.967681
# [157]	valid_0's rmse: 0.967681
# [158]	valid_0's rmse: 0.967681
# [159]	valid_0's rmse: 0.967681
# [160]	valid_0's rmse: 0.967681
# [161]	valid_0's rmse: 0.967681
# [162]	valid_0's rmse: 0.967681
# [163]	valid_0's rmse: 0.967681
# [164]	valid_0's rmse: 0.967681
# [165]	valid_0's rmse: 0.967681
# [166]	valid_0's rmse: 0.967681
# [167]	valid_0's rmse: 0.967681
# [168]	valid_0's rmse: 0.967681
# [169]	valid_0's rmse: 0.967681
# [170]	valid_0's rmse: 0.967681
# [171]	valid_0's rmse: 0.967681
# [172]	valid_0's rmse: 0.967681
# [173]	valid_0's rmse: 0.967681
# [174]	valid_0's rmse: 0.967681
# [175]	valid_0's rmse: 0.967681
# [176]	valid_0's rmse: 0.967681
# [177]	valid_0's rmse: 0.967681
# [178]	valid_0's rmse: 0.967681
# [179]	valid_0's rmse: 0.967681
# [180]	valid_0's rmse: 0.967681
# [181]	valid_0's rmse: 0.967681
# [182]	valid_0's rmse: 0.967681
# [183]	valid_0's rmse: 0.967681
# [184]	valid_0's rmse: 0.967681
# [185]	valid_0's rmse: 0.967681
# [186]	valid_0's rmse: 0.967681
# [187]	valid_0's rmse: 0.967681
# [188]	valid_0's rmse: 0.967681
# [189]	valid_0's rmse: 0.967681
# [190]	valid_0's rmse: 0.967681
# [191]	valid_0's rmse: 0.967681
# [192]	valid_0's rmse: 0.967681
# [193]	valid_0's rmse: 0.967681
# [194]	valid_0's rmse: 0.967681
# [195]	valid_0's rmse: 0.967681
# [196]	valid_0's rmse: 0.967681
# [197]	valid_0's rmse: 0.967681
# [198]	valid_0's rmse: 0.967681
# [199]	valid_0's rmse: 0.967681
# [200]	valid_0's rmse: 0.967681
# [201]	valid_0's rmse: 0.967681
# [202]	valid_0's rmse: 0.967681
# [203]	valid_0's rmse: 0.967681
# Early stopping, best iteration is:
# [103]	valid_0's rmse: 0.967672
# 1
# [1]	valid_0's rmse: 1.07028
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.05891
# [3]	valid_0's rmse: 1.04757
# [4]	valid_0's rmse: 1.03806
# [5]	valid_0's rmse: 1.02918
# [6]	valid_0's rmse: 1.02252
# [7]	valid_0's rmse: 1.01692
# [8]	valid_0's rmse: 1.01199
# [9]	valid_0's rmse: 1.0084
# [10]	valid_0's rmse: 1.00488
# [11]	valid_0's rmse: 1.00158
# [12]	valid_0's rmse: 0.99882
# [13]	valid_0's rmse: 0.996054
# [14]	valid_0's rmse: 0.993667
# [15]	valid_0's rmse: 0.991508
# [16]	valid_0's rmse: 0.989737
# [17]	valid_0's rmse: 0.98839
# [18]	valid_0's rmse: 0.986829
# [19]	valid_0's rmse: 0.985608
# [20]	valid_0's rmse: 0.984407
# [21]	valid_0's rmse: 0.98326
# [22]	valid_0's rmse: 0.982196
# [23]	valid_0's rmse: 0.981306
# [24]	valid_0's rmse: 0.980389
# [25]	valid_0's rmse: 0.979563
# [26]	valid_0's rmse: 0.978965
# [27]	valid_0's rmse: 0.978473
# [28]	valid_0's rmse: 0.977929
# [29]	valid_0's rmse: 0.977337
# [30]	valid_0's rmse: 0.976882
# [31]	valid_0's rmse: 0.976292
# [32]	valid_0's rmse: 0.976
# [33]	valid_0's rmse: 0.975615
# [34]	valid_0's rmse: 0.975342
# [35]	valid_0's rmse: 0.975056
# [36]	valid_0's rmse: 0.974824
# [37]	valid_0's rmse: 0.974621
# [38]	valid_0's rmse: 0.974183
# [39]	valid_0's rmse: 0.974074
# [40]	valid_0's rmse: 0.973856
# [41]	valid_0's rmse: 0.973457
# [42]	valid_0's rmse: 0.973242
# [43]	valid_0's rmse: 0.972996
# [44]	valid_0's rmse: 0.972878
# [45]	valid_0's rmse: 0.972636
# [46]	valid_0's rmse: 0.972488
# [47]	valid_0's rmse: 0.972295
# [48]	valid_0's rmse: 0.972151
# [49]	valid_0's rmse: 0.971945
# [50]	valid_0's rmse: 0.971825
# [51]	valid_0's rmse: 0.971704
# [52]	valid_0's rmse: 0.971579
# [53]	valid_0's rmse: 0.971511
# [54]	valid_0's rmse: 0.971372
# [55]	valid_0's rmse: 0.971325
# [56]	valid_0's rmse: 0.971268
# [57]	valid_0's rmse: 0.971199
# [58]	valid_0's rmse: 0.971089
# [59]	valid_0's rmse: 0.971003
# [60]	valid_0's rmse: 0.970925
# [61]	valid_0's rmse: 0.970839
# [62]	valid_0's rmse: 0.970834
# [63]	valid_0's rmse: 0.970771
# [64]	valid_0's rmse: 0.970691
# [65]	valid_0's rmse: 0.970633
# [66]	valid_0's rmse: 0.970607
# [67]	valid_0's rmse: 0.970552
# [68]	valid_0's rmse: 0.970448
# [69]	valid_0's rmse: 0.970391
# [70]	valid_0's rmse: 0.970388
# [71]	valid_0's rmse: 0.970325
# [72]	valid_0's rmse: 0.970319
# [73]	valid_0's rmse: 0.970246
# [74]	valid_0's rmse: 0.970149
# [75]	valid_0's rmse: 0.970137
# [76]	valid_0's rmse: 0.970114
# [77]	valid_0's rmse: 0.970096
# [78]	valid_0's rmse: 0.970062
# [79]	valid_0's rmse: 0.970054
# [80]	valid_0's rmse: 0.970041
# [81]	valid_0's rmse: 0.970023
# [82]	valid_0's rmse: 0.969981
# [83]	valid_0's rmse: 0.96995
# [84]	valid_0's rmse: 0.969948
# [85]	valid_0's rmse: 0.969935
# [86]	valid_0's rmse: 0.969926
# [87]	valid_0's rmse: 0.969907
# [88]	valid_0's rmse: 0.969879
# [89]	valid_0's rmse: 0.969857
# [90]	valid_0's rmse: 0.969838
# [91]	valid_0's rmse: 0.969815
# [92]	valid_0's rmse: 0.969801
# [93]	valid_0's rmse: 0.969791
# [94]	valid_0's rmse: 0.969785
# [95]	valid_0's rmse: 0.969783
# [96]	valid_0's rmse: 0.969758
# [97]	valid_0's rmse: 0.969757
# [98]	valid_0's rmse: 0.969749
# [99]	valid_0's rmse: 0.969744
# [100]	valid_0's rmse: 0.969738
# [101]	valid_0's rmse: 0.969735
# [102]	valid_0's rmse: 0.969731
# [103]	valid_0's rmse: 0.969729
# [104]	valid_0's rmse: 0.969721
# [105]	valid_0's rmse: 0.969721
# [106]	valid_0's rmse: 0.969722
# [107]	valid_0's rmse: 0.969723
# [108]	valid_0's rmse: 0.969723
# [109]	valid_0's rmse: 0.969723
# [110]	valid_0's rmse: 0.969723
# [111]	valid_0's rmse: 0.969723
# [112]	valid_0's rmse: 0.969723
# [113]	valid_0's rmse: 0.969723
# [114]	valid_0's rmse: 0.969723
# [115]	valid_0's rmse: 0.969723
# [116]	valid_0's rmse: 0.969723
# [117]	valid_0's rmse: 0.969723
# [118]	valid_0's rmse: 0.969723
# [119]	valid_0's rmse: 0.969723
# [120]	valid_0's rmse: 0.969723
# [121]	valid_0's rmse: 0.969723
# [122]	valid_0's rmse: 0.969723
# [123]	valid_0's rmse: 0.969723
# [124]	valid_0's rmse: 0.969723
# [125]	valid_0's rmse: 0.969723
# [126]	valid_0's rmse: 0.969723
# [127]	valid_0's rmse: 0.969723
# [128]	valid_0's rmse: 0.969723
# [129]	valid_0's rmse: 0.969723
# [130]	valid_0's rmse: 0.969723
# [131]	valid_0's rmse: 0.969723
# [132]	valid_0's rmse: 0.969723
# [133]	valid_0's rmse: 0.969723
# [134]	valid_0's rmse: 0.969723
# [135]	valid_0's rmse: 0.969723
# [136]	valid_0's rmse: 0.969723
# [137]	valid_0's rmse: 0.969723
# [138]	valid_0's rmse: 0.969723
# [139]	valid_0's rmse: 0.969723
# [140]	valid_0's rmse: 0.969723
# [141]	valid_0's rmse: 0.969723
# [142]	valid_0's rmse: 0.969723
# [143]	valid_0's rmse: 0.969723
# [144]	valid_0's rmse: 0.969723
# [145]	valid_0's rmse: 0.969723
# [146]	valid_0's rmse: 0.969723
# [147]	valid_0's rmse: 0.969723
# [148]	valid_0's rmse: 0.969723
# [149]	valid_0's rmse: 0.969723
# [150]	valid_0's rmse: 0.969723
# [151]	valid_0's rmse: 0.969723
# [152]	valid_0's rmse: 0.969723
# [153]	valid_0's rmse: 0.969723
# [154]	valid_0's rmse: 0.969723
# [155]	valid_0's rmse: 0.969723
# [156]	valid_0's rmse: 0.969723
# [157]	valid_0's rmse: 0.969723
# [158]	valid_0's rmse: 0.969723
# [159]	valid_0's rmse: 0.969723
# [160]	valid_0's rmse: 0.969723
# [161]	valid_0's rmse: 0.969723
# [162]	valid_0's rmse: 0.969723
# [163]	valid_0's rmse: 0.969723
# [164]	valid_0's rmse: 0.969723
# [165]	valid_0's rmse: 0.969723
# [166]	valid_0's rmse: 0.969723
# [167]	valid_0's rmse: 0.969723
# [168]	valid_0's rmse: 0.969723
# [169]	valid_0's rmse: 0.969723
# [170]	valid_0's rmse: 0.969723
# [171]	valid_0's rmse: 0.969723
# [172]	valid_0's rmse: 0.969723
# [173]	valid_0's rmse: 0.969723
# [174]	valid_0's rmse: 0.969723
# [175]	valid_0's rmse: 0.969723
# [176]	valid_0's rmse: 0.969723
# [177]	valid_0's rmse: 0.969723
# [178]	valid_0's rmse: 0.969723
# [179]	valid_0's rmse: 0.969723
# [180]	valid_0's rmse: 0.969723
# [181]	valid_0's rmse: 0.969723
# [182]	valid_0's rmse: 0.969723
# [183]	valid_0's rmse: 0.969723
# [184]	valid_0's rmse: 0.969723
# [185]	valid_0's rmse: 0.969723
# [186]	valid_0's rmse: 0.969723
# [187]	valid_0's rmse: 0.969723
# [188]	valid_0's rmse: 0.969723
# [189]	valid_0's rmse: 0.969723
# [190]	valid_0's rmse: 0.969723
# [191]	valid_0's rmse: 0.969723
# [192]	valid_0's rmse: 0.969723
# [193]	valid_0's rmse: 0.969723
# [194]	valid_0's rmse: 0.969723
# [195]	valid_0's rmse: 0.969723
# [196]	valid_0's rmse: 0.969723
# [197]	valid_0's rmse: 0.969723
# [198]	valid_0's rmse: 0.969723
# [199]	valid_0's rmse: 0.969723
# [200]	valid_0's rmse: 0.969723
# [201]	valid_0's rmse: 0.969723
# [202]	valid_0's rmse: 0.969723
# [203]	valid_0's rmse: 0.969723
# [204]	valid_0's rmse: 0.969723
# Early stopping, best iteration is:
# [104]	valid_0's rmse: 0.969721
# 2
# [1]	valid_0's rmse: 1.0786
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.06702
# [3]	valid_0's rmse: 1.0557
# [4]	valid_0's rmse: 1.04614
# [5]	valid_0's rmse: 1.03728
# [6]	valid_0's rmse: 1.03055
# [7]	valid_0's rmse: 1.02499
# [8]	valid_0's rmse: 1.02011
# [9]	valid_0's rmse: 1.01641
# [10]	valid_0's rmse: 1.01274
# [11]	valid_0's rmse: 1.0095
# [12]	valid_0's rmse: 1.00672
# [13]	valid_0's rmse: 1.00389
# [14]	valid_0's rmse: 1.0015
# [15]	valid_0's rmse: 0.999316
# [16]	valid_0's rmse: 0.997622
# [17]	valid_0's rmse: 0.9962
# [18]	valid_0's rmse: 0.99444
# [19]	valid_0's rmse: 0.993104
# [20]	valid_0's rmse: 0.991979
# [21]	valid_0's rmse: 0.990628
# [22]	valid_0's rmse: 0.989704
# [23]	valid_0's rmse: 0.988946
# [24]	valid_0's rmse: 0.987984
# [25]	valid_0's rmse: 0.987179
# [26]	valid_0's rmse: 0.986597
# [27]	valid_0's rmse: 0.986051
# [28]	valid_0's rmse: 0.985394
# [29]	valid_0's rmse: 0.984744
# [30]	valid_0's rmse: 0.984179
# [31]	valid_0's rmse: 0.983572
# [32]	valid_0's rmse: 0.983265
# [33]	valid_0's rmse: 0.983053
# [34]	valid_0's rmse: 0.982745
# [35]	valid_0's rmse: 0.982535
# [36]	valid_0's rmse: 0.98229
# [37]	valid_0's rmse: 0.982092
# [38]	valid_0's rmse: 0.981775
# [39]	valid_0's rmse: 0.981633
# [40]	valid_0's rmse: 0.981292
# [41]	valid_0's rmse: 0.980855
# [42]	valid_0's rmse: 0.980688
# [43]	valid_0's rmse: 0.98039
# [44]	valid_0's rmse: 0.980241
# [45]	valid_0's rmse: 0.980022
# [46]	valid_0's rmse: 0.979848
# [47]	valid_0's rmse: 0.979582
# [48]	valid_0's rmse: 0.979439
# [49]	valid_0's rmse: 0.979205
# [50]	valid_0's rmse: 0.979077
# [51]	valid_0's rmse: 0.978979
# [52]	valid_0's rmse: 0.978875
# [53]	valid_0's rmse: 0.978814
# [54]	valid_0's rmse: 0.978617
# [55]	valid_0's rmse: 0.97858
# [56]	valid_0's rmse: 0.978547
# [57]	valid_0's rmse: 0.978492
# [58]	valid_0's rmse: 0.978366
# [59]	valid_0's rmse: 0.978245
# [60]	valid_0's rmse: 0.978141
# [61]	valid_0's rmse: 0.978056
# [62]	valid_0's rmse: 0.978013
# [63]	valid_0's rmse: 0.977895
# [64]	valid_0's rmse: 0.977819
# [65]	valid_0's rmse: 0.977719
# [66]	valid_0's rmse: 0.977692
# [67]	valid_0's rmse: 0.977594
# [68]	valid_0's rmse: 0.977562
# [69]	valid_0's rmse: 0.977541
# [70]	valid_0's rmse: 0.977476
# [71]	valid_0's rmse: 0.977429
# [72]	valid_0's rmse: 0.977416
# [73]	valid_0's rmse: 0.977378
# [74]	valid_0's rmse: 0.977348
# [75]	valid_0's rmse: 0.97731
# [76]	valid_0's rmse: 0.977292
# [77]	valid_0's rmse: 0.977243
# [78]	valid_0's rmse: 0.977222
# [79]	valid_0's rmse: 0.977219
# [80]	valid_0's rmse: 0.977154
# [81]	valid_0's rmse: 0.977107
# [82]	valid_0's rmse: 0.977066
# [83]	valid_0's rmse: 0.977052
# [84]	valid_0's rmse: 0.97704
# [85]	valid_0's rmse: 0.97703
# [86]	valid_0's rmse: 0.977024
# [87]	valid_0's rmse: 0.977003
# [88]	valid_0's rmse: 0.977004
# [89]	valid_0's rmse: 0.977004
# [90]	valid_0's rmse: 0.97699
# [91]	valid_0's rmse: 0.976969
# [92]	valid_0's rmse: 0.976972
# [93]	valid_0's rmse: 0.976974
# [94]	valid_0's rmse: 0.976975
# [95]	valid_0's rmse: 0.976932
# [96]	valid_0's rmse: 0.976929
# [97]	valid_0's rmse: 0.976929
# [98]	valid_0's rmse: 0.976929
# [99]	valid_0's rmse: 0.976929
# [100]	valid_0's rmse: 0.976929
# [101]	valid_0's rmse: 0.976929
# [102]	valid_0's rmse: 0.976929
# [103]	valid_0's rmse: 0.976929
# [104]	valid_0's rmse: 0.976929
# [105]	valid_0's rmse: 0.976929
# [106]	valid_0's rmse: 0.976929
# [107]	valid_0's rmse: 0.976929
# [108]	valid_0's rmse: 0.976929
# [109]	valid_0's rmse: 0.976929
# [110]	valid_0's rmse: 0.976929
# [111]	valid_0's rmse: 0.976929
# [112]	valid_0's rmse: 0.976929
# [113]	valid_0's rmse: 0.976929
# [114]	valid_0's rmse: 0.976929
# [115]	valid_0's rmse: 0.976929
# [116]	valid_0's rmse: 0.976929
# [117]	valid_0's rmse: 0.976929
# [118]	valid_0's rmse: 0.976929
# [119]	valid_0's rmse: 0.976929
# [120]	valid_0's rmse: 0.976929
# [121]	valid_0's rmse: 0.976929
# [122]	valid_0's rmse: 0.976929
# [123]	valid_0's rmse: 0.976929
# [124]	valid_0's rmse: 0.976929
# [125]	valid_0's rmse: 0.976929
# [126]	valid_0's rmse: 0.976929
# [127]	valid_0's rmse: 0.976929
# [128]	valid_0's rmse: 0.976929
# [129]	valid_0's rmse: 0.976929
# [130]	valid_0's rmse: 0.976929
# [131]	valid_0's rmse: 0.976929
# [132]	valid_0's rmse: 0.976929
# [133]	valid_0's rmse: 0.976929
# [134]	valid_0's rmse: 0.976929
# [135]	valid_0's rmse: 0.976929
# [136]	valid_0's rmse: 0.976929
# [137]	valid_0's rmse: 0.976929
# [138]	valid_0's rmse: 0.976929
# [139]	valid_0's rmse: 0.976929
# [140]	valid_0's rmse: 0.976929
# [141]	valid_0's rmse: 0.976929
# [142]	valid_0's rmse: 0.976929
# [143]	valid_0's rmse: 0.976929
# [144]	valid_0's rmse: 0.976929
# [145]	valid_0's rmse: 0.976929
# [146]	valid_0's rmse: 0.976929
# [147]	valid_0's rmse: 0.976929
# [148]	valid_0's rmse: 0.976929
# [149]	valid_0's rmse: 0.976929
# [150]	valid_0's rmse: 0.976929
# [151]	valid_0's rmse: 0.976929
# [152]	valid_0's rmse: 0.976929
# [153]	valid_0's rmse: 0.976929
# [154]	valid_0's rmse: 0.976929
# [155]	valid_0's rmse: 0.976929
# [156]	valid_0's rmse: 0.976929
# [157]	valid_0's rmse: 0.976929
# [158]	valid_0's rmse: 0.976929
# [159]	valid_0's rmse: 0.976929
# [160]	valid_0's rmse: 0.976929
# [161]	valid_0's rmse: 0.976929
# [162]	valid_0's rmse: 0.976929
# [163]	valid_0's rmse: 0.976929
# [164]	valid_0's rmse: 0.976929
# [165]	valid_0's rmse: 0.976929
# [166]	valid_0's rmse: 0.976929
# [167]	valid_0's rmse: 0.976929
# [168]	valid_0's rmse: 0.976929
# [169]	valid_0's rmse: 0.976929
# [170]	valid_0's rmse: 0.976929
# [171]	valid_0's rmse: 0.976929
# [172]	valid_0's rmse: 0.976929
# [173]	valid_0's rmse: 0.976929
# [174]	valid_0's rmse: 0.976929
# [175]	valid_0's rmse: 0.976929
# [176]	valid_0's rmse: 0.976929
# [177]	valid_0's rmse: 0.976929
# [178]	valid_0's rmse: 0.976929
# [179]	valid_0's rmse: 0.976929
# [180]	valid_0's rmse: 0.976929
# [181]	valid_0's rmse: 0.976929
# [182]	valid_0's rmse: 0.976929
# [183]	valid_0's rmse: 0.976929
# [184]	valid_0's rmse: 0.976929
# [185]	valid_0's rmse: 0.976929
# [186]	valid_0's rmse: 0.976929
# [187]	valid_0's rmse: 0.976929
# [188]	valid_0's rmse: 0.976929
# [189]	valid_0's rmse: 0.976929
# [190]	valid_0's rmse: 0.976929
# [191]	valid_0's rmse: 0.976929
# [192]	valid_0's rmse: 0.976929
# [193]	valid_0's rmse: 0.976929
# [194]	valid_0's rmse: 0.976929
# [195]	valid_0's rmse: 0.976929
# [196]	valid_0's rmse: 0.976929
# Early stopping, best iteration is:
# [96]	valid_0's rmse: 0.976929
# 3
# [1]	valid_0's rmse: 1.06702
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.05534
# [3]	valid_0's rmse: 1.04402
# [4]	valid_0's rmse: 1.03463
# [5]	valid_0's rmse: 1.02576
# [6]	valid_0's rmse: 1.01907
# [7]	valid_0's rmse: 1.0136
# [8]	valid_0's rmse: 1.00869
# [9]	valid_0's rmse: 1.00501
# [10]	valid_0's rmse: 1.0014
# [11]	valid_0's rmse: 0.998209
# [12]	valid_0's rmse: 0.995193
# [13]	valid_0's rmse: 0.992319
# [14]	valid_0's rmse: 0.989635
# [15]	valid_0's rmse: 0.987526
# [16]	valid_0's rmse: 0.985597
# [17]	valid_0's rmse: 0.984173
# [18]	valid_0's rmse: 0.982359
# [19]	valid_0's rmse: 0.980973
# [20]	valid_0's rmse: 0.979791
# [21]	valid_0's rmse: 0.978567
# [22]	valid_0's rmse: 0.977603
# [23]	valid_0's rmse: 0.976613
# [24]	valid_0's rmse: 0.975728
# [25]	valid_0's rmse: 0.974835
# [26]	valid_0's rmse: 0.974169
# [27]	valid_0's rmse: 0.973472
# [28]	valid_0's rmse: 0.972829
# [29]	valid_0's rmse: 0.972157
# [30]	valid_0's rmse: 0.971682
# [31]	valid_0's rmse: 0.971179
# [32]	valid_0's rmse: 0.970827
# [33]	valid_0's rmse: 0.970506
# [34]	valid_0's rmse: 0.970144
# [35]	valid_0's rmse: 0.96982
# [36]	valid_0's rmse: 0.969559
# [37]	valid_0's rmse: 0.969329
# [38]	valid_0's rmse: 0.968984
# [39]	valid_0's rmse: 0.968832
# [40]	valid_0's rmse: 0.968502
# [41]	valid_0's rmse: 0.967977
# [42]	valid_0's rmse: 0.96777
# [43]	valid_0's rmse: 0.967352
# [44]	valid_0's rmse: 0.967163
# [45]	valid_0's rmse: 0.967041
# [46]	valid_0's rmse: 0.966942
# [47]	valid_0's rmse: 0.966623
# [48]	valid_0's rmse: 0.96645
# [49]	valid_0's rmse: 0.96621
# [50]	valid_0's rmse: 0.966065
# [51]	valid_0's rmse: 0.965945
# [52]	valid_0's rmse: 0.965837
# [53]	valid_0's rmse: 0.965771
# [54]	valid_0's rmse: 0.965603
# [55]	valid_0's rmse: 0.96553
# [56]	valid_0's rmse: 0.96541
# [57]	valid_0's rmse: 0.965327
# [58]	valid_0's rmse: 0.965163
# [59]	valid_0's rmse: 0.965052
# [60]	valid_0's rmse: 0.964935
# [61]	valid_0's rmse: 0.964853
# [62]	valid_0's rmse: 0.964823
# [63]	valid_0's rmse: 0.964743
# [64]	valid_0's rmse: 0.964687
# [65]	valid_0's rmse: 0.964524
# [66]	valid_0's rmse: 0.964481
# [67]	valid_0's rmse: 0.964378
# [68]	valid_0's rmse: 0.964341
# [69]	valid_0's rmse: 0.96431
# [70]	valid_0's rmse: 0.964249
# [71]	valid_0's rmse: 0.964174
# [72]	valid_0's rmse: 0.964159
# [73]	valid_0's rmse: 0.964118
# [74]	valid_0's rmse: 0.964098
# [75]	valid_0's rmse: 0.964062
# [76]	valid_0's rmse: 0.964038
# [77]	valid_0's rmse: 0.963996
# [78]	valid_0's rmse: 0.963955
# [79]	valid_0's rmse: 0.96394
# [80]	valid_0's rmse: 0.963891
# [81]	valid_0's rmse: 0.963867
# [82]	valid_0's rmse: 0.963838
# [83]	valid_0's rmse: 0.963807
# [84]	valid_0's rmse: 0.963772
# [85]	valid_0's rmse: 0.963761
# [86]	valid_0's rmse: 0.963773
# [87]	valid_0's rmse: 0.963751
# [88]	valid_0's rmse: 0.963737
# [89]	valid_0's rmse: 0.963703
# [90]	valid_0's rmse: 0.963677
# [91]	valid_0's rmse: 0.963661
# [92]	valid_0's rmse: 0.963651
# [93]	valid_0's rmse: 0.963641
# [94]	valid_0's rmse: 0.963644
# [95]	valid_0's rmse: 0.963624
# [96]	valid_0's rmse: 0.963614
# [97]	valid_0's rmse: 0.963614
# [98]	valid_0's rmse: 0.963599
# [99]	valid_0's rmse: 0.963599
# [100]	valid_0's rmse: 0.963572
# [101]	valid_0's rmse: 0.96351
# [102]	valid_0's rmse: 0.963496
# [103]	valid_0's rmse: 0.963481
# [104]	valid_0's rmse: 0.963471
# [105]	valid_0's rmse: 0.963466
# [106]	valid_0's rmse: 0.963466
# [107]	valid_0's rmse: 0.963466
# [108]	valid_0's rmse: 0.963466
# [109]	valid_0's rmse: 0.963466
# [110]	valid_0's rmse: 0.963469
# [111]	valid_0's rmse: 0.963469
# [112]	valid_0's rmse: 0.963469
# [113]	valid_0's rmse: 0.963469
# [114]	valid_0's rmse: 0.963469
# [115]	valid_0's rmse: 0.963469
# [116]	valid_0's rmse: 0.963469
# [117]	valid_0's rmse: 0.963469
# [118]	valid_0's rmse: 0.963469
# [119]	valid_0's rmse: 0.963469
# [120]	valid_0's rmse: 0.963469
# [121]	valid_0's rmse: 0.963469
# [122]	valid_0's rmse: 0.963469
# [123]	valid_0's rmse: 0.963469
# [124]	valid_0's rmse: 0.963469
# [125]	valid_0's rmse: 0.963469
# [126]	valid_0's rmse: 0.963469
# [127]	valid_0's rmse: 0.963469
# [128]	valid_0's rmse: 0.963469
# [129]	valid_0's rmse: 0.963469
# [130]	valid_0's rmse: 0.963469
# [131]	valid_0's rmse: 0.963469
# [132]	valid_0's rmse: 0.963469
# [133]	valid_0's rmse: 0.963469
# [134]	valid_0's rmse: 0.963469
# [135]	valid_0's rmse: 0.963469
# [136]	valid_0's rmse: 0.963469
# [137]	valid_0's rmse: 0.963469
# [138]	valid_0's rmse: 0.963469
# [139]	valid_0's rmse: 0.963469
# [140]	valid_0's rmse: 0.963469
# [141]	valid_0's rmse: 0.963469
# [142]	valid_0's rmse: 0.963469
# [143]	valid_0's rmse: 0.963469
# [144]	valid_0's rmse: 0.963469
# [145]	valid_0's rmse: 0.963469
# [146]	valid_0's rmse: 0.963469
# [147]	valid_0's rmse: 0.963469
# [148]	valid_0's rmse: 0.963469
# [149]	valid_0's rmse: 0.963469
# [150]	valid_0's rmse: 0.963469
# [151]	valid_0's rmse: 0.963469
# [152]	valid_0's rmse: 0.963469
# [153]	valid_0's rmse: 0.963469
# [154]	valid_0's rmse: 0.963469
# [155]	valid_0's rmse: 0.963469
# [156]	valid_0's rmse: 0.963469
# [157]	valid_0's rmse: 0.963469
# [158]	valid_0's rmse: 0.963469
# [159]	valid_0's rmse: 0.963469
# [160]	valid_0's rmse: 0.963469
# [161]	valid_0's rmse: 0.963469
# [162]	valid_0's rmse: 0.963469
# [163]	valid_0's rmse: 0.963469
# [164]	valid_0's rmse: 0.963469
# [165]	valid_0's rmse: 0.963469
# [166]	valid_0's rmse: 0.963469
# [167]	valid_0's rmse: 0.963469
# [168]	valid_0's rmse: 0.963469
# [169]	valid_0's rmse: 0.963469
# [170]	valid_0's rmse: 0.963469
# [171]	valid_0's rmse: 0.963469
# [172]	valid_0's rmse: 0.963469
# [173]	valid_0's rmse: 0.963469
# [174]	valid_0's rmse: 0.963469
# [175]	valid_0's rmse: 0.963469
# [176]	valid_0's rmse: 0.963469
# [177]	valid_0's rmse: 0.963469
# [178]	valid_0's rmse: 0.963469
# [179]	valid_0's rmse: 0.963469
# [180]	valid_0's rmse: 0.963469
# [181]	valid_0's rmse: 0.963469
# [182]	valid_0's rmse: 0.963469
# [183]	valid_0's rmse: 0.963469
# [184]	valid_0's rmse: 0.963469
# [185]	valid_0's rmse: 0.963469
# [186]	valid_0's rmse: 0.963469
# [187]	valid_0's rmse: 0.963469
# [188]	valid_0's rmse: 0.963469
# [189]	valid_0's rmse: 0.963469
# [190]	valid_0's rmse: 0.963469
# [191]	valid_0's rmse: 0.963469
# [192]	valid_0's rmse: 0.963469
# [193]	valid_0's rmse: 0.963469
# [194]	valid_0's rmse: 0.963469
# [195]	valid_0's rmse: 0.963469
# [196]	valid_0's rmse: 0.963469
# [197]	valid_0's rmse: 0.963469
# [198]	valid_0's rmse: 0.963469
# [199]	valid_0's rmse: 0.963469
# [200]	valid_0's rmse: 0.963469
# [201]	valid_0's rmse: 0.963469
# [202]	valid_0's rmse: 0.963469
# [203]	valid_0's rmse: 0.963469
# [204]	valid_0's rmse: 0.963469
# [205]	valid_0's rmse: 0.963469
# Early stopping, best iteration is:
# [105]	valid_0's rmse: 0.963466
# 4
# [1]	valid_0's rmse: 1.07069
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.05914
# [3]	valid_0's rmse: 1.04749
# [4]	valid_0's rmse: 1.03761
# [5]	valid_0's rmse: 1.02847
# [6]	valid_0's rmse: 1.02162
# [7]	valid_0's rmse: 1.01588
# [8]	valid_0's rmse: 1.01085
# [9]	valid_0's rmse: 1.00696
# [10]	valid_0's rmse: 1.0033
# [11]	valid_0's rmse: 0.999784
# [12]	valid_0's rmse: 0.997021
# [13]	valid_0's rmse: 0.994088
# [14]	valid_0's rmse: 0.991598
# [15]	valid_0's rmse: 0.989388
# [16]	valid_0's rmse: 0.987578
# [17]	valid_0's rmse: 0.986136
# [18]	valid_0's rmse: 0.984333
# [19]	valid_0's rmse: 0.982935
# [20]	valid_0's rmse: 0.981814
# [21]	valid_0's rmse: 0.98056
# [22]	valid_0's rmse: 0.979522
# [23]	valid_0's rmse: 0.978626
# [24]	valid_0's rmse: 0.977712
# [25]	valid_0's rmse: 0.976887
# [26]	valid_0's rmse: 0.976228
# [27]	valid_0's rmse: 0.975705
# [28]	valid_0's rmse: 0.975063
# [29]	valid_0's rmse: 0.974518
# [30]	valid_0's rmse: 0.973988
# [31]	valid_0's rmse: 0.973395
# [32]	valid_0's rmse: 0.973004
# [33]	valid_0's rmse: 0.972668
# [34]	valid_0's rmse: 0.972386
# [35]	valid_0's rmse: 0.972138
# [36]	valid_0's rmse: 0.971925
# [37]	valid_0's rmse: 0.971722
# [38]	valid_0's rmse: 0.971489
# [39]	valid_0's rmse: 0.971296
# [40]	valid_0's rmse: 0.970932
# [41]	valid_0's rmse: 0.970512
# [42]	valid_0's rmse: 0.970287
# [43]	valid_0's rmse: 0.969925
# [44]	valid_0's rmse: 0.969752
# [45]	valid_0's rmse: 0.969585
# [46]	valid_0's rmse: 0.969426
# [47]	valid_0's rmse: 0.969153
# [48]	valid_0's rmse: 0.969017
# [49]	valid_0's rmse: 0.968806
# [50]	valid_0's rmse: 0.968668
# [51]	valid_0's rmse: 0.968591
# [52]	valid_0's rmse: 0.968495
# [53]	valid_0's rmse: 0.968395
# [54]	valid_0's rmse: 0.968242
# [55]	valid_0's rmse: 0.968196
# [56]	valid_0's rmse: 0.96813
# [57]	valid_0's rmse: 0.968032
# [58]	valid_0's rmse: 0.967886
# [59]	valid_0's rmse: 0.967791
# [60]	valid_0's rmse: 0.96768
# [61]	valid_0's rmse: 0.96759
# [62]	valid_0's rmse: 0.967572
# [63]	valid_0's rmse: 0.967474
# [64]	valid_0's rmse: 0.96743
# [65]	valid_0's rmse: 0.96735
# [66]	valid_0's rmse: 0.967333
# [67]	valid_0's rmse: 0.967276
# [68]	valid_0's rmse: 0.967199
# [69]	valid_0's rmse: 0.967174
# [70]	valid_0's rmse: 0.967153
# [71]	valid_0's rmse: 0.967104
# [72]	valid_0's rmse: 0.967066
# [73]	valid_0's rmse: 0.96704
# [74]	valid_0's rmse: 0.966917
# [75]	valid_0's rmse: 0.966891
# [76]	valid_0's rmse: 0.966872
# [77]	valid_0's rmse: 0.966816
# [78]	valid_0's rmse: 0.966762
# [79]	valid_0's rmse: 0.966746
# [80]	valid_0's rmse: 0.966696
# [81]	valid_0's rmse: 0.966647
# [82]	valid_0's rmse: 0.966594
# [83]	valid_0's rmse: 0.966566
# [84]	valid_0's rmse: 0.966546
# [85]	valid_0's rmse: 0.966531
# [86]	valid_0's rmse: 0.966502
# [87]	valid_0's rmse: 0.966473
# [88]	valid_0's rmse: 0.966472
# [89]	valid_0's rmse: 0.966464
# [90]	valid_0's rmse: 0.96644
# [91]	valid_0's rmse: 0.96643
# [92]	valid_0's rmse: 0.96643
# [93]	valid_0's rmse: 0.96642
# [94]	valid_0's rmse: 0.966395
# [95]	valid_0's rmse: 0.966384
# [96]	valid_0's rmse: 0.966368
# [97]	valid_0's rmse: 0.966364
# [98]	valid_0's rmse: 0.966352
# [99]	valid_0's rmse: 0.966352
# [100]	valid_0's rmse: 0.966346
# [101]	valid_0's rmse: 0.966328
# [102]	valid_0's rmse: 0.966315
# [103]	valid_0's rmse: 0.966296
# [104]	valid_0's rmse: 0.966294
# [105]	valid_0's rmse: 0.966275
# [106]	valid_0's rmse: 0.966274
# [107]	valid_0's rmse: 0.966274
# [108]	valid_0's rmse: 0.966274
# [109]	valid_0's rmse: 0.966274
# [110]	valid_0's rmse: 0.966272
# [111]	valid_0's rmse: 0.966272
# [112]	valid_0's rmse: 0.966272
# [113]	valid_0's rmse: 0.966272
# [114]	valid_0's rmse: 0.966272
# [115]	valid_0's rmse: 0.966272
# [116]	valid_0's rmse: 0.966272
# [117]	valid_0's rmse: 0.966272
# [118]	valid_0's rmse: 0.966272
# [119]	valid_0's rmse: 0.966272
# [120]	valid_0's rmse: 0.966272
# [121]	valid_0's rmse: 0.966272
# [122]	valid_0's rmse: 0.966272
# [123]	valid_0's rmse: 0.966272
# [124]	valid_0's rmse: 0.966272
# [125]	valid_0's rmse: 0.966272
# [126]	valid_0's rmse: 0.966272
# [127]	valid_0's rmse: 0.966272
# [128]	valid_0's rmse: 0.966272
# [129]	valid_0's rmse: 0.966272
# [130]	valid_0's rmse: 0.966272
# [131]	valid_0's rmse: 0.966272
# [132]	valid_0's rmse: 0.966272
# [133]	valid_0's rmse: 0.966272
# [134]	valid_0's rmse: 0.966272
# [135]	valid_0's rmse: 0.966272
# [136]	valid_0's rmse: 0.966272
# [137]	valid_0's rmse: 0.966272
# [138]	valid_0's rmse: 0.966272
# [139]	valid_0's rmse: 0.966272
# [140]	valid_0's rmse: 0.966272
# [141]	valid_0's rmse: 0.966272
# [142]	valid_0's rmse: 0.966272
# [143]	valid_0's rmse: 0.966272
# [144]	valid_0's rmse: 0.966272
# [145]	valid_0's rmse: 0.966272
# [146]	valid_0's rmse: 0.966272
# [147]	valid_0's rmse: 0.966272
# [148]	valid_0's rmse: 0.966272
# [149]	valid_0's rmse: 0.966272
# [150]	valid_0's rmse: 0.966272
# [151]	valid_0's rmse: 0.966272
# [152]	valid_0's rmse: 0.966272
# [153]	valid_0's rmse: 0.966272
# [154]	valid_0's rmse: 0.966272
# [155]	valid_0's rmse: 0.966272
# [156]	valid_0's rmse: 0.966272
# [157]	valid_0's rmse: 0.966272
# [158]	valid_0's rmse: 0.966272
# [159]	valid_0's rmse: 0.966272
# [160]	valid_0's rmse: 0.966272
# [161]	valid_0's rmse: 0.966272
# [162]	valid_0's rmse: 0.966272
# [163]	valid_0's rmse: 0.966272
# [164]	valid_0's rmse: 0.966272
# [165]	valid_0's rmse: 0.966272
# [166]	valid_0's rmse: 0.966272
# [167]	valid_0's rmse: 0.966272
# [168]	valid_0's rmse: 0.966272
# [169]	valid_0's rmse: 0.966272
# [170]	valid_0's rmse: 0.966272
# [171]	valid_0's rmse: 0.966272
# [172]	valid_0's rmse: 0.966272
# [173]	valid_0's rmse: 0.966272
# [174]	valid_0's rmse: 0.966272
# [175]	valid_0's rmse: 0.966272
# [176]	valid_0's rmse: 0.966272
# [177]	valid_0's rmse: 0.966272
# [178]	valid_0's rmse: 0.966272
# [179]	valid_0's rmse: 0.966272
# [180]	valid_0's rmse: 0.966272
# [181]	valid_0's rmse: 0.966272
# [182]	valid_0's rmse: 0.966272
# [183]	valid_0's rmse: 0.966272
# [184]	valid_0's rmse: 0.966272
# [185]	valid_0's rmse: 0.966272
# [186]	valid_0's rmse: 0.966272
# [187]	valid_0's rmse: 0.966272
# [188]	valid_0's rmse: 0.966272
# [189]	valid_0's rmse: 0.966272
# [190]	valid_0's rmse: 0.966272
# [191]	valid_0's rmse: 0.966272
# [192]	valid_0's rmse: 0.966272
# [193]	valid_0's rmse: 0.966272
# [194]	valid_0's rmse: 0.966272
# [195]	valid_0's rmse: 0.966272
# [196]	valid_0's rmse: 0.966272
# [197]	valid_0's rmse: 0.966272
# [198]	valid_0's rmse: 0.966272
# [199]	valid_0's rmse: 0.966272
# [200]	valid_0's rmse: 0.966272
# [201]	valid_0's rmse: 0.966272
# [202]	valid_0's rmse: 0.966272
# [203]	valid_0's rmse: 0.966272
# [204]	valid_0's rmse: 0.966272
# [205]	valid_0's rmse: 0.966272
# [206]	valid_0's rmse: 0.966272
# [207]	valid_0's rmse: 0.966272
# [208]	valid_0's rmse: 0.966272
# [209]	valid_0's rmse: 0.966272
# [210]	valid_0's rmse: 0.966272
# Early stopping, best iteration is:
# [110]	valid_0's rmse: 0.966272
# 5
# [1]	valid_0's rmse: 1.08209
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.07032
# [3]	valid_0's rmse: 1.05878
# [4]	valid_0's rmse: 1.04906
# [5]	valid_0's rmse: 1.03988
# [6]	valid_0's rmse: 1.03291
# [7]	valid_0's rmse: 1.02734
# [8]	valid_0's rmse: 1.02211
# [9]	valid_0's rmse: 1.01826
# [10]	valid_0's rmse: 1.01453
# [11]	valid_0's rmse: 1.01105
# [12]	valid_0's rmse: 1.00811
# [13]	valid_0's rmse: 1.00517
# [14]	valid_0's rmse: 1.00259
# [15]	valid_0's rmse: 1.00025
# [16]	valid_0's rmse: 0.998332
# [17]	valid_0's rmse: 0.996759
# [18]	valid_0's rmse: 0.995057
# [19]	valid_0's rmse: 0.993649
# [20]	valid_0's rmse: 0.99256
# [21]	valid_0's rmse: 0.991281
# [22]	valid_0's rmse: 0.990212
# [23]	valid_0's rmse: 0.989276
# [24]	valid_0's rmse: 0.988381
# [25]	valid_0's rmse: 0.987491
# [26]	valid_0's rmse: 0.986893
# [27]	valid_0's rmse: 0.986354
# [28]	valid_0's rmse: 0.985761
# [29]	valid_0's rmse: 0.985096
# [30]	valid_0's rmse: 0.984545
# [31]	valid_0's rmse: 0.98395
# [32]	valid_0's rmse: 0.983571
# [33]	valid_0's rmse: 0.983182
# [34]	valid_0's rmse: 0.982796
# [35]	valid_0's rmse: 0.982523
# [36]	valid_0's rmse: 0.982237
# [37]	valid_0's rmse: 0.98194
# [38]	valid_0's rmse: 0.981571
# [39]	valid_0's rmse: 0.981347
# [40]	valid_0's rmse: 0.981032
# [41]	valid_0's rmse: 0.980638
# [42]	valid_0's rmse: 0.980489
# [43]	valid_0's rmse: 0.980179
# [44]	valid_0's rmse: 0.979972
# [45]	valid_0's rmse: 0.979756
# [46]	valid_0's rmse: 0.979544
# [47]	valid_0's rmse: 0.97929
# [48]	valid_0's rmse: 0.979102
# [49]	valid_0's rmse: 0.978894
# [50]	valid_0's rmse: 0.978738
# [51]	valid_0's rmse: 0.978661
# [52]	valid_0's rmse: 0.97846
# [53]	valid_0's rmse: 0.978381
# [54]	valid_0's rmse: 0.978188
# [55]	valid_0's rmse: 0.978115
# [56]	valid_0's rmse: 0.978051
# [57]	valid_0's rmse: 0.977964
# [58]	valid_0's rmse: 0.977872
# [59]	valid_0's rmse: 0.977767
# [60]	valid_0's rmse: 0.977709
# [61]	valid_0's rmse: 0.977613
# [62]	valid_0's rmse: 0.97756
# [63]	valid_0's rmse: 0.977481
# [64]	valid_0's rmse: 0.977441
# [65]	valid_0's rmse: 0.977365
# [66]	valid_0's rmse: 0.977353
# [67]	valid_0's rmse: 0.977293
# [68]	valid_0's rmse: 0.977214
# [69]	valid_0's rmse: 0.97719
# [70]	valid_0's rmse: 0.977123
# [71]	valid_0's rmse: 0.977064
# [72]	valid_0's rmse: 0.977043
# [73]	valid_0's rmse: 0.977009
# [74]	valid_0's rmse: 0.976979
# [75]	valid_0's rmse: 0.976958
# [76]	valid_0's rmse: 0.976944
# [77]	valid_0's rmse: 0.976901
# [78]	valid_0's rmse: 0.976878
# [79]	valid_0's rmse: 0.976862
# [80]	valid_0's rmse: 0.976792
# [81]	valid_0's rmse: 0.976776
# [82]	valid_0's rmse: 0.976762
# [83]	valid_0's rmse: 0.976742
# [84]	valid_0's rmse: 0.976712
# [85]	valid_0's rmse: 0.976708
# [86]	valid_0's rmse: 0.976702
# [87]	valid_0's rmse: 0.976674
# [88]	valid_0's rmse: 0.976664
# [89]	valid_0's rmse: 0.976619
# [90]	valid_0's rmse: 0.976603
# [91]	valid_0's rmse: 0.97658
# [92]	valid_0's rmse: 0.976562
# [93]	valid_0's rmse: 0.976552
# [94]	valid_0's rmse: 0.976541
# [95]	valid_0's rmse: 0.976528
# [96]	valid_0's rmse: 0.976528
# [97]	valid_0's rmse: 0.976522
# [98]	valid_0's rmse: 0.976522
# [99]	valid_0's rmse: 0.976522
# [100]	valid_0's rmse: 0.976522
# [101]	valid_0's rmse: 0.976522
# [102]	valid_0's rmse: 0.976522
# [103]	valid_0's rmse: 0.976522
# [104]	valid_0's rmse: 0.976522
# [105]	valid_0's rmse: 0.976522
# [106]	valid_0's rmse: 0.976522
# [107]	valid_0's rmse: 0.976522
# [108]	valid_0's rmse: 0.976522
# [109]	valid_0's rmse: 0.976522
# [110]	valid_0's rmse: 0.976522
# [111]	valid_0's rmse: 0.976522
# [112]	valid_0's rmse: 0.976522
# [113]	valid_0's rmse: 0.976522
# [114]	valid_0's rmse: 0.976522
# [115]	valid_0's rmse: 0.976522
# [116]	valid_0's rmse: 0.976522
# [117]	valid_0's rmse: 0.976522
# [118]	valid_0's rmse: 0.976522
# [119]	valid_0's rmse: 0.976522
# [120]	valid_0's rmse: 0.976522
# [121]	valid_0's rmse: 0.976522
# [122]	valid_0's rmse: 0.976522
# [123]	valid_0's rmse: 0.976522
# [124]	valid_0's rmse: 0.976522
# [125]	valid_0's rmse: 0.976522
# [126]	valid_0's rmse: 0.976522
# [127]	valid_0's rmse: 0.976522
# [128]	valid_0's rmse: 0.976522
# [129]	valid_0's rmse: 0.976522
# [130]	valid_0's rmse: 0.976522
# [131]	valid_0's rmse: 0.976522
# [132]	valid_0's rmse: 0.976522
# [133]	valid_0's rmse: 0.976522
# [134]	valid_0's rmse: 0.976522
# [135]	valid_0's rmse: 0.976522
# [136]	valid_0's rmse: 0.976522
# [137]	valid_0's rmse: 0.976522
# [138]	valid_0's rmse: 0.976522
# [139]	valid_0's rmse: 0.976522
# [140]	valid_0's rmse: 0.976522
# [141]	valid_0's rmse: 0.976522
# [142]	valid_0's rmse: 0.976522
# [143]	valid_0's rmse: 0.976522
# [144]	valid_0's rmse: 0.976522
# [145]	valid_0's rmse: 0.976522
# [146]	valid_0's rmse: 0.976522
# [147]	valid_0's rmse: 0.976522
# [148]	valid_0's rmse: 0.976522
# [149]	valid_0's rmse: 0.976522
# [150]	valid_0's rmse: 0.976522
# [151]	valid_0's rmse: 0.976522
# [152]	valid_0's rmse: 0.976522
# [153]	valid_0's rmse: 0.976522
# [154]	valid_0's rmse: 0.976522
# [155]	valid_0's rmse: 0.976522
# [156]	valid_0's rmse: 0.976522
# [157]	valid_0's rmse: 0.976522
# [158]	valid_0's rmse: 0.976522
# [159]	valid_0's rmse: 0.976522
# [160]	valid_0's rmse: 0.976522
# [161]	valid_0's rmse: 0.976522
# [162]	valid_0's rmse: 0.976522
# [163]	valid_0's rmse: 0.976522
# [164]	valid_0's rmse: 0.976522
# [165]	valid_0's rmse: 0.976522
# [166]	valid_0's rmse: 0.976522
# [167]	valid_0's rmse: 0.976522
# [168]	valid_0's rmse: 0.976522
# [169]	valid_0's rmse: 0.976522
# [170]	valid_0's rmse: 0.976522
# [171]	valid_0's rmse: 0.976522
# [172]	valid_0's rmse: 0.976522
# [173]	valid_0's rmse: 0.976522
# [174]	valid_0's rmse: 0.976522
# [175]	valid_0's rmse: 0.976522
# [176]	valid_0's rmse: 0.976522
# [177]	valid_0's rmse: 0.976522
# [178]	valid_0's rmse: 0.976522
# [179]	valid_0's rmse: 0.976522
# [180]	valid_0's rmse: 0.976522
# [181]	valid_0's rmse: 0.976522
# [182]	valid_0's rmse: 0.976522
# [183]	valid_0's rmse: 0.976522
# [184]	valid_0's rmse: 0.976522
# [185]	valid_0's rmse: 0.976522
# [186]	valid_0's rmse: 0.976522
# [187]	valid_0's rmse: 0.976522
# [188]	valid_0's rmse: 0.976522
# [189]	valid_0's rmse: 0.976522
# [190]	valid_0's rmse: 0.976522
# [191]	valid_0's rmse: 0.976522
# [192]	valid_0's rmse: 0.976522
# [193]	valid_0's rmse: 0.976522
# [194]	valid_0's rmse: 0.976522
# [195]	valid_0's rmse: 0.976522
# [196]	valid_0's rmse: 0.976522
# [197]	valid_0's rmse: 0.976522
# Early stopping, best iteration is:
# [97]	valid_0's rmse: 0.976522
# 6
# [1]	valid_0's rmse: 1.07275
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.06141
# [3]	valid_0's rmse: 1.05018
# [4]	valid_0's rmse: 1.04082
# [5]	valid_0's rmse: 1.0321
# [6]	valid_0's rmse: 1.02557
# [7]	valid_0's rmse: 1.02002
# [8]	valid_0's rmse: 1.01508
# [9]	valid_0's rmse: 1.01146
# [10]	valid_0's rmse: 1.00793
# [11]	valid_0's rmse: 1.00462
# [12]	valid_0's rmse: 1.00191
# [13]	valid_0's rmse: 0.999048
# [14]	valid_0's rmse: 0.996685
# [15]	valid_0's rmse: 0.994548
# [16]	valid_0's rmse: 0.992705
# [17]	valid_0's rmse: 0.991306
# [18]	valid_0's rmse: 0.98965
# [19]	valid_0's rmse: 0.988351
# [20]	valid_0's rmse: 0.987243
# [21]	valid_0's rmse: 0.986061
# [22]	valid_0's rmse: 0.985082
# [23]	valid_0's rmse: 0.984206
# [24]	valid_0's rmse: 0.983291
# [25]	valid_0's rmse: 0.982363
# [26]	valid_0's rmse: 0.981797
# [27]	valid_0's rmse: 0.981327
# [28]	valid_0's rmse: 0.980759
# [29]	valid_0's rmse: 0.980221
# [30]	valid_0's rmse: 0.979807
# [31]	valid_0's rmse: 0.97919
# [32]	valid_0's rmse: 0.978815
# [33]	valid_0's rmse: 0.978523
# [34]	valid_0's rmse: 0.978221
# [35]	valid_0's rmse: 0.977999
# [36]	valid_0's rmse: 0.977779
# [37]	valid_0's rmse: 0.977573
# [38]	valid_0's rmse: 0.97733
# [39]	valid_0's rmse: 0.977175
# [40]	valid_0's rmse: 0.976893
# [41]	valid_0's rmse: 0.976564
# [42]	valid_0's rmse: 0.976294
# [43]	valid_0's rmse: 0.975967
# [44]	valid_0's rmse: 0.975787
# [45]	valid_0's rmse: 0.975568
# [46]	valid_0's rmse: 0.975463
# [47]	valid_0's rmse: 0.975303
# [48]	valid_0's rmse: 0.975173
# [49]	valid_0's rmse: 0.974994
# [50]	valid_0's rmse: 0.97491
# [51]	valid_0's rmse: 0.974838
# [52]	valid_0's rmse: 0.974732
# [53]	valid_0's rmse: 0.974642
# [54]	valid_0's rmse: 0.974443
# [55]	valid_0's rmse: 0.97439
# [56]	valid_0's rmse: 0.974329
# [57]	valid_0's rmse: 0.974314
# [58]	valid_0's rmse: 0.974165
# [59]	valid_0's rmse: 0.974074
# [60]	valid_0's rmse: 0.973995
# [61]	valid_0's rmse: 0.973936
# [62]	valid_0's rmse: 0.973869
# [63]	valid_0's rmse: 0.973816
# [64]	valid_0's rmse: 0.973785
# [65]	valid_0's rmse: 0.973728
# [66]	valid_0's rmse: 0.973673
# [67]	valid_0's rmse: 0.973607
# [68]	valid_0's rmse: 0.973557
# [69]	valid_0's rmse: 0.973531
# [70]	valid_0's rmse: 0.973493
# [71]	valid_0's rmse: 0.973472
# [72]	valid_0's rmse: 0.973443
# [73]	valid_0's rmse: 0.973422
# [74]	valid_0's rmse: 0.973388
# [75]	valid_0's rmse: 0.973366
# [76]	valid_0's rmse: 0.97333
# [77]	valid_0's rmse: 0.973285
# [78]	valid_0's rmse: 0.973252
# [79]	valid_0's rmse: 0.973241
# [80]	valid_0's rmse: 0.973193
# [81]	valid_0's rmse: 0.97315
# [82]	valid_0's rmse: 0.973108
# [83]	valid_0's rmse: 0.973089
# [84]	valid_0's rmse: 0.973075
# [85]	valid_0's rmse: 0.973062
# [86]	valid_0's rmse: 0.973029
# [87]	valid_0's rmse: 0.973013
# [88]	valid_0's rmse: 0.97301
# [89]	valid_0's rmse: 0.972996
# [90]	valid_0's rmse: 0.972983
# [91]	valid_0's rmse: 0.972964
# [92]	valid_0's rmse: 0.972957
# [93]	valid_0's rmse: 0.97295
# [94]	valid_0's rmse: 0.972937
# [95]	valid_0's rmse: 0.972937
# [96]	valid_0's rmse: 0.972925
# [97]	valid_0's rmse: 0.972921
# [98]	valid_0's rmse: 0.972906
# [99]	valid_0's rmse: 0.972898
# [100]	valid_0's rmse: 0.972878
# [101]	valid_0's rmse: 0.972858
# [102]	valid_0's rmse: 0.972851
# [103]	valid_0's rmse: 0.972846
# [104]	valid_0's rmse: 0.972837
# [105]	valid_0's rmse: 0.972837
# [106]	valid_0's rmse: 0.972835
# [107]	valid_0's rmse: 0.972821
# [108]	valid_0's rmse: 0.972815
# [109]	valid_0's rmse: 0.972816
# [110]	valid_0's rmse: 0.972816
# [111]	valid_0's rmse: 0.972816
# [112]	valid_0's rmse: 0.972816
# [113]	valid_0's rmse: 0.972816
# [114]	valid_0's rmse: 0.972816
# [115]	valid_0's rmse: 0.972816
# [116]	valid_0's rmse: 0.972816
# [117]	valid_0's rmse: 0.972816
# [118]	valid_0's rmse: 0.972816
# [119]	valid_0's rmse: 0.972816
# [120]	valid_0's rmse: 0.972816
# [121]	valid_0's rmse: 0.972816
# [122]	valid_0's rmse: 0.972816
# [123]	valid_0's rmse: 0.972816
# [124]	valid_0's rmse: 0.972816
# [125]	valid_0's rmse: 0.972816
# [126]	valid_0's rmse: 0.972816
# [127]	valid_0's rmse: 0.972816
# [128]	valid_0's rmse: 0.972816
# [129]	valid_0's rmse: 0.972816
# [130]	valid_0's rmse: 0.972816
# [131]	valid_0's rmse: 0.972816
# [132]	valid_0's rmse: 0.972816
# [133]	valid_0's rmse: 0.972816
# [134]	valid_0's rmse: 0.972816
# [135]	valid_0's rmse: 0.972816
# [136]	valid_0's rmse: 0.972816
# [137]	valid_0's rmse: 0.972816
# [138]	valid_0's rmse: 0.972816
# [139]	valid_0's rmse: 0.972816
# [140]	valid_0's rmse: 0.972816
# [141]	valid_0's rmse: 0.972816
# [142]	valid_0's rmse: 0.972816
# [143]	valid_0's rmse: 0.972816
# [144]	valid_0's rmse: 0.972816
# [145]	valid_0's rmse: 0.972816
# [146]	valid_0's rmse: 0.972816
# [147]	valid_0's rmse: 0.972816
# [148]	valid_0's rmse: 0.972816
# [149]	valid_0's rmse: 0.972816
# [150]	valid_0's rmse: 0.972816
# [151]	valid_0's rmse: 0.972816
# [152]	valid_0's rmse: 0.972816
# [153]	valid_0's rmse: 0.972816
# [154]	valid_0's rmse: 0.972816
# [155]	valid_0's rmse: 0.972816
# [156]	valid_0's rmse: 0.972816
# [157]	valid_0's rmse: 0.972816
# [158]	valid_0's rmse: 0.972816
# [159]	valid_0's rmse: 0.972816
# [160]	valid_0's rmse: 0.972816
# [161]	valid_0's rmse: 0.972816
# [162]	valid_0's rmse: 0.972816
# [163]	valid_0's rmse: 0.972816
# [164]	valid_0's rmse: 0.972816
# [165]	valid_0's rmse: 0.972816
# [166]	valid_0's rmse: 0.972816
# [167]	valid_0's rmse: 0.972816
# [168]	valid_0's rmse: 0.972816
# [169]	valid_0's rmse: 0.972816
# [170]	valid_0's rmse: 0.972816
# [171]	valid_0's rmse: 0.972816
# [172]	valid_0's rmse: 0.972816
# [173]	valid_0's rmse: 0.972816
# [174]	valid_0's rmse: 0.972816
# [175]	valid_0's rmse: 0.972816
# [176]	valid_0's rmse: 0.972816
# [177]	valid_0's rmse: 0.972816
# [178]	valid_0's rmse: 0.972816
# [179]	valid_0's rmse: 0.972816
# [180]	valid_0's rmse: 0.972816
# [181]	valid_0's rmse: 0.972816
# [182]	valid_0's rmse: 0.972816
# [183]	valid_0's rmse: 0.972816
# [184]	valid_0's rmse: 0.972816
# [185]	valid_0's rmse: 0.972816
# [186]	valid_0's rmse: 0.972816
# [187]	valid_0's rmse: 0.972816
# [188]	valid_0's rmse: 0.972816
# [189]	valid_0's rmse: 0.972816
# [190]	valid_0's rmse: 0.972816
# [191]	valid_0's rmse: 0.972816
# [192]	valid_0's rmse: 0.972816
# [193]	valid_0's rmse: 0.972816
# [194]	valid_0's rmse: 0.972816
# [195]	valid_0's rmse: 0.972816
# [196]	valid_0's rmse: 0.972816
# [197]	valid_0's rmse: 0.972816
# [198]	valid_0's rmse: 0.972816
# [199]	valid_0's rmse: 0.972816
# [200]	valid_0's rmse: 0.972816
# [201]	valid_0's rmse: 0.972816
# [202]	valid_0's rmse: 0.972816
# [203]	valid_0's rmse: 0.972816
# [204]	valid_0's rmse: 0.972816
# [205]	valid_0's rmse: 0.972816
# [206]	valid_0's rmse: 0.972816
# [207]	valid_0's rmse: 0.972816
# [208]	valid_0's rmse: 0.972816
# Early stopping, best iteration is:
# [108]	valid_0's rmse: 0.972815
# 7
# [1]	valid_0's rmse: 1.0722
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.06066
# [3]	valid_0's rmse: 1.04932
# [4]	valid_0's rmse: 1.03983
# [5]	valid_0's rmse: 1.03098
# [6]	valid_0's rmse: 1.02421
# [7]	valid_0's rmse: 1.01873
# [8]	valid_0's rmse: 1.01376
# [9]	valid_0's rmse: 1.01008
# [10]	valid_0's rmse: 1.00638
# [11]	valid_0's rmse: 1.00295
# [12]	valid_0's rmse: 1.00014
# [13]	valid_0's rmse: 0.997284
# [14]	valid_0's rmse: 0.994837
# [15]	valid_0's rmse: 0.992702
# [16]	valid_0's rmse: 0.990925
# [17]	valid_0's rmse: 0.989471
# [18]	valid_0's rmse: 0.987668
# [19]	valid_0's rmse: 0.9864
# [20]	valid_0's rmse: 0.985382
# [21]	valid_0's rmse: 0.984087
# [22]	valid_0's rmse: 0.98315
# [23]	valid_0's rmse: 0.982193
# [24]	valid_0's rmse: 0.98126
# [25]	valid_0's rmse: 0.980368
# [26]	valid_0's rmse: 0.979696
# [27]	valid_0's rmse: 0.979125
# [28]	valid_0's rmse: 0.978481
# [29]	valid_0's rmse: 0.97794
# [30]	valid_0's rmse: 0.977392
# [31]	valid_0's rmse: 0.976792
# [32]	valid_0's rmse: 0.976496
# [33]	valid_0's rmse: 0.976186
# [34]	valid_0's rmse: 0.975806
# [35]	valid_0's rmse: 0.975532
# [36]	valid_0's rmse: 0.975321
# [37]	valid_0's rmse: 0.97514
# [38]	valid_0's rmse: 0.974819
# [39]	valid_0's rmse: 0.974669
# [40]	valid_0's rmse: 0.974339
# [41]	valid_0's rmse: 0.973975
# [42]	valid_0's rmse: 0.973747
# [43]	valid_0's rmse: 0.973452
# [44]	valid_0's rmse: 0.973306
# [45]	valid_0's rmse: 0.973183
# [46]	valid_0's rmse: 0.973046
# [47]	valid_0's rmse: 0.972763
# [48]	valid_0's rmse: 0.972594
# [49]	valid_0's rmse: 0.972363
# [50]	valid_0's rmse: 0.972195
# [51]	valid_0's rmse: 0.972094
# [52]	valid_0's rmse: 0.971981
# [53]	valid_0's rmse: 0.971913
# [54]	valid_0's rmse: 0.971772
# [55]	valid_0's rmse: 0.971698
# [56]	valid_0's rmse: 0.971649
# [57]	valid_0's rmse: 0.971613
# [58]	valid_0's rmse: 0.971464
# [59]	valid_0's rmse: 0.97143
# [60]	valid_0's rmse: 0.971314
# [61]	valid_0's rmse: 0.971227
# [62]	valid_0's rmse: 0.971185
# [63]	valid_0's rmse: 0.971091
# [64]	valid_0's rmse: 0.971051
# [65]	valid_0's rmse: 0.970985
# [66]	valid_0's rmse: 0.970938
# [67]	valid_0's rmse: 0.970792
# [68]	valid_0's rmse: 0.970726
# [69]	valid_0's rmse: 0.970667
# [70]	valid_0's rmse: 0.970631
# [71]	valid_0's rmse: 0.970596
# [72]	valid_0's rmse: 0.970584
# [73]	valid_0's rmse: 0.970526
# [74]	valid_0's rmse: 0.970502
# [75]	valid_0's rmse: 0.970501
# [76]	valid_0's rmse: 0.970481
# [77]	valid_0's rmse: 0.970452
# [78]	valid_0's rmse: 0.970421
# [79]	valid_0's rmse: 0.970411
# [80]	valid_0's rmse: 0.970364
# [81]	valid_0's rmse: 0.970337
# [82]	valid_0's rmse: 0.970302
# [83]	valid_0's rmse: 0.970268
# [84]	valid_0's rmse: 0.970226
# [85]	valid_0's rmse: 0.970219
# [86]	valid_0's rmse: 0.970206
# [87]	valid_0's rmse: 0.970196
# [88]	valid_0's rmse: 0.970187
# [89]	valid_0's rmse: 0.97015
# [90]	valid_0's rmse: 0.970148
# [91]	valid_0's rmse: 0.97011
# [92]	valid_0's rmse: 0.970102
# [93]	valid_0's rmse: 0.970086
# [94]	valid_0's rmse: 0.970086
# [95]	valid_0's rmse: 0.970084
# [96]	valid_0's rmse: 0.97008
# [97]	valid_0's rmse: 0.970076
# [98]	valid_0's rmse: 0.970055
# [99]	valid_0's rmse: 0.970055
# [100]	valid_0's rmse: 0.970055
# [101]	valid_0's rmse: 0.970055
# [102]	valid_0's rmse: 0.970055
# [103]	valid_0's rmse: 0.970055
# [104]	valid_0's rmse: 0.970055
# [105]	valid_0's rmse: 0.970055
# [106]	valid_0's rmse: 0.970055
# [107]	valid_0's rmse: 0.970055
# [108]	valid_0's rmse: 0.970055
# [109]	valid_0's rmse: 0.970055
# [110]	valid_0's rmse: 0.970055
# [111]	valid_0's rmse: 0.970055
# [112]	valid_0's rmse: 0.970055
# [113]	valid_0's rmse: 0.970055
# [114]	valid_0's rmse: 0.970055
# [115]	valid_0's rmse: 0.970055
# [116]	valid_0's rmse: 0.970055
# [117]	valid_0's rmse: 0.970055
# [118]	valid_0's rmse: 0.970055
# [119]	valid_0's rmse: 0.970055
# [120]	valid_0's rmse: 0.970055
# [121]	valid_0's rmse: 0.970055
# [122]	valid_0's rmse: 0.970055
# [123]	valid_0's rmse: 0.970055
# [124]	valid_0's rmse: 0.970055
# [125]	valid_0's rmse: 0.970055
# [126]	valid_0's rmse: 0.970055
# [127]	valid_0's rmse: 0.970055
# [128]	valid_0's rmse: 0.970055
# [129]	valid_0's rmse: 0.970055
# [130]	valid_0's rmse: 0.970055
# [131]	valid_0's rmse: 0.970055
# [132]	valid_0's rmse: 0.970055
# [133]	valid_0's rmse: 0.970055
# [134]	valid_0's rmse: 0.970055
# [135]	valid_0's rmse: 0.970055
# [136]	valid_0's rmse: 0.970055
# [137]	valid_0's rmse: 0.970055
# [138]	valid_0's rmse: 0.970055
# [139]	valid_0's rmse: 0.970055
# [140]	valid_0's rmse: 0.970055
# [141]	valid_0's rmse: 0.970055
# [142]	valid_0's rmse: 0.970055
# [143]	valid_0's rmse: 0.970055
# [144]	valid_0's rmse: 0.970055
# [145]	valid_0's rmse: 0.970055
# [146]	valid_0's rmse: 0.970055
# [147]	valid_0's rmse: 0.970055
# [148]	valid_0's rmse: 0.970055
# [149]	valid_0's rmse: 0.970055
# [150]	valid_0's rmse: 0.970055
# [151]	valid_0's rmse: 0.970055
# [152]	valid_0's rmse: 0.970055
# [153]	valid_0's rmse: 0.970055
# [154]	valid_0's rmse: 0.970055
# [155]	valid_0's rmse: 0.970055
# [156]	valid_0's rmse: 0.970055
# [157]	valid_0's rmse: 0.970055
# [158]	valid_0's rmse: 0.970055
# [159]	valid_0's rmse: 0.970055
# [160]	valid_0's rmse: 0.970055
# [161]	valid_0's rmse: 0.970055
# [162]	valid_0's rmse: 0.970055
# [163]	valid_0's rmse: 0.970055
# [164]	valid_0's rmse: 0.970055
# [165]	valid_0's rmse: 0.970055
# [166]	valid_0's rmse: 0.970055
# [167]	valid_0's rmse: 0.970055
# [168]	valid_0's rmse: 0.970055
# [169]	valid_0's rmse: 0.970055
# [170]	valid_0's rmse: 0.970055
# [171]	valid_0's rmse: 0.970055
# [172]	valid_0's rmse: 0.970055
# [173]	valid_0's rmse: 0.970055
# [174]	valid_0's rmse: 0.970055
# [175]	valid_0's rmse: 0.970055
# [176]	valid_0's rmse: 0.970055
# [177]	valid_0's rmse: 0.970055
# [178]	valid_0's rmse: 0.970055
# [179]	valid_0's rmse: 0.970055
# [180]	valid_0's rmse: 0.970055
# [181]	valid_0's rmse: 0.970055
# [182]	valid_0's rmse: 0.970055
# [183]	valid_0's rmse: 0.970055
# [184]	valid_0's rmse: 0.970055
# [185]	valid_0's rmse: 0.970055
# [186]	valid_0's rmse: 0.970055
# [187]	valid_0's rmse: 0.970055
# [188]	valid_0's rmse: 0.970055
# [189]	valid_0's rmse: 0.970055
# [190]	valid_0's rmse: 0.970055
# [191]	valid_0's rmse: 0.970055
# [192]	valid_0's rmse: 0.970055
# [193]	valid_0's rmse: 0.970055
# [194]	valid_0's rmse: 0.970055
# [195]	valid_0's rmse: 0.970055
# [196]	valid_0's rmse: 0.970055
# [197]	valid_0's rmse: 0.970055
# [198]	valid_0's rmse: 0.970055
# [199]	valid_0's rmse: 0.970055
# [200]	valid_0's rmse: 0.970055
# [201]	valid_0's rmse: 0.970055
# [202]	valid_0's rmse: 0.970055
# [203]	valid_0's rmse: 0.970055
# Early stopping, best iteration is:
# [103]	valid_0's rmse: 0.970055
# 8
# [1]	valid_0's rmse: 1.06845
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.0571
# [3]	valid_0's rmse: 1.04566
# [4]	valid_0's rmse: 1.0362
# [5]	valid_0's rmse: 1.02748
# [6]	valid_0's rmse: 1.02086
# [7]	valid_0's rmse: 1.01526
# [8]	valid_0's rmse: 1.01024
# [9]	valid_0's rmse: 1.00666
# [10]	valid_0's rmse: 1.00305
# [11]	valid_0's rmse: 0.999811
# [12]	valid_0's rmse: 0.997073
# [13]	valid_0's rmse: 0.994299
# [14]	valid_0's rmse: 0.991853
# [15]	valid_0's rmse: 0.9898
# [16]	valid_0's rmse: 0.987999
# [17]	valid_0's rmse: 0.986638
# [18]	valid_0's rmse: 0.984969
# [19]	valid_0's rmse: 0.983669
# [20]	valid_0's rmse: 0.982476
# [21]	valid_0's rmse: 0.981245
# [22]	valid_0's rmse: 0.980266
# [23]	valid_0's rmse: 0.979357
# [24]	valid_0's rmse: 0.978469
# [25]	valid_0's rmse: 0.977692
# [26]	valid_0's rmse: 0.977112
# [27]	valid_0's rmse: 0.976498
# [28]	valid_0's rmse: 0.975924
# [29]	valid_0's rmse: 0.975329
# [30]	valid_0's rmse: 0.974855
# [31]	valid_0's rmse: 0.974228
# [32]	valid_0's rmse: 0.973876
# [33]	valid_0's rmse: 0.973619
# [34]	valid_0's rmse: 0.973354
# [35]	valid_0's rmse: 0.973048
# [36]	valid_0's rmse: 0.972805
# [37]	valid_0's rmse: 0.972602
# [38]	valid_0's rmse: 0.972278
# [39]	valid_0's rmse: 0.972081
# [40]	valid_0's rmse: 0.971696
# [41]	valid_0's rmse: 0.971348
# [42]	valid_0's rmse: 0.971099
# [43]	valid_0's rmse: 0.970754
# [44]	valid_0's rmse: 0.970521
# [45]	valid_0's rmse: 0.970343
# [46]	valid_0's rmse: 0.970189
# [47]	valid_0's rmse: 0.969952
# [48]	valid_0's rmse: 0.969811
# [49]	valid_0's rmse: 0.969587
# [50]	valid_0's rmse: 0.969419
# [51]	valid_0's rmse: 0.969314
# [52]	valid_0's rmse: 0.969223
# [53]	valid_0's rmse: 0.969141
# [54]	valid_0's rmse: 0.969057
# [55]	valid_0's rmse: 0.968962
# [56]	valid_0's rmse: 0.96889
# [57]	valid_0's rmse: 0.96878
# [58]	valid_0's rmse: 0.96865
# [59]	valid_0's rmse: 0.96851
# [60]	valid_0's rmse: 0.968382
# [61]	valid_0's rmse: 0.96828
# [62]	valid_0's rmse: 0.968236
# [63]	valid_0's rmse: 0.968151
# [64]	valid_0's rmse: 0.968101
# [65]	valid_0's rmse: 0.968018
# [66]	valid_0's rmse: 0.967931
# [67]	valid_0's rmse: 0.967867
# [68]	valid_0's rmse: 0.967774
# [69]	valid_0's rmse: 0.967729
# [70]	valid_0's rmse: 0.96767
# [71]	valid_0's rmse: 0.967583
# [72]	valid_0's rmse: 0.967544
# [73]	valid_0's rmse: 0.967503
# [74]	valid_0's rmse: 0.967469
# [75]	valid_0's rmse: 0.967453
# [76]	valid_0's rmse: 0.967423
# [77]	valid_0's rmse: 0.967327
# [78]	valid_0's rmse: 0.967295
# [79]	valid_0's rmse: 0.967278
# [80]	valid_0's rmse: 0.967258
# [81]	valid_0's rmse: 0.967228
# [82]	valid_0's rmse: 0.967197
# [83]	valid_0's rmse: 0.967165
# [84]	valid_0's rmse: 0.967128
# [85]	valid_0's rmse: 0.967119
# [86]	valid_0's rmse: 0.967117
# [87]	valid_0's rmse: 0.967115
# [88]	valid_0's rmse: 0.96708
# [89]	valid_0's rmse: 0.967051
# [90]	valid_0's rmse: 0.967037
# [91]	valid_0's rmse: 0.96701
# [92]	valid_0's rmse: 0.966945
# [93]	valid_0's rmse: 0.966947
# [94]	valid_0's rmse: 0.966945
# [95]	valid_0's rmse: 0.966931
# [96]	valid_0's rmse: 0.966916
# [97]	valid_0's rmse: 0.966919
# [98]	valid_0's rmse: 0.966919
# [99]	valid_0's rmse: 0.966919
# [100]	valid_0's rmse: 0.966919
# [101]	valid_0's rmse: 0.966919
# [102]	valid_0's rmse: 0.966919
# [103]	valid_0's rmse: 0.966919
# [104]	valid_0's rmse: 0.966919
# [105]	valid_0's rmse: 0.966919
# [106]	valid_0's rmse: 0.966919
# [107]	valid_0's rmse: 0.966919
# [108]	valid_0's rmse: 0.966919
# [109]	valid_0's rmse: 0.966919
# [110]	valid_0's rmse: 0.966919
# [111]	valid_0's rmse: 0.966919
# [112]	valid_0's rmse: 0.966919
# [113]	valid_0's rmse: 0.966919
# [114]	valid_0's rmse: 0.966919
# [115]	valid_0's rmse: 0.966919
# [116]	valid_0's rmse: 0.966919
# [117]	valid_0's rmse: 0.966919
# [118]	valid_0's rmse: 0.966919
# [119]	valid_0's rmse: 0.966919
# [120]	valid_0's rmse: 0.966919
# [121]	valid_0's rmse: 0.966919
# [122]	valid_0's rmse: 0.966919
# [123]	valid_0's rmse: 0.966919
# [124]	valid_0's rmse: 0.966919
# [125]	valid_0's rmse: 0.966919
# [126]	valid_0's rmse: 0.966919
# [127]	valid_0's rmse: 0.966919
# [128]	valid_0's rmse: 0.966919
# [129]	valid_0's rmse: 0.966919
# [130]	valid_0's rmse: 0.966919
# [131]	valid_0's rmse: 0.966919
# [132]	valid_0's rmse: 0.966919
# [133]	valid_0's rmse: 0.966919
# [134]	valid_0's rmse: 0.966919
# [135]	valid_0's rmse: 0.966919
# [136]	valid_0's rmse: 0.966919
# [137]	valid_0's rmse: 0.966919
# [138]	valid_0's rmse: 0.966919
# [139]	valid_0's rmse: 0.966919
# [140]	valid_0's rmse: 0.966919
# [141]	valid_0's rmse: 0.966919
# [142]	valid_0's rmse: 0.966919
# [143]	valid_0's rmse: 0.966919
# [144]	valid_0's rmse: 0.966919
# [145]	valid_0's rmse: 0.966919
# [146]	valid_0's rmse: 0.966919
# [147]	valid_0's rmse: 0.966919
# [148]	valid_0's rmse: 0.966919
# [149]	valid_0's rmse: 0.966919
# [150]	valid_0's rmse: 0.966919
# [151]	valid_0's rmse: 0.966919
# [152]	valid_0's rmse: 0.966919
# [153]	valid_0's rmse: 0.966919
# [154]	valid_0's rmse: 0.966919
# [155]	valid_0's rmse: 0.966919
# [156]	valid_0's rmse: 0.966919
# [157]	valid_0's rmse: 0.966919
# [158]	valid_0's rmse: 0.966919
# [159]	valid_0's rmse: 0.966919
# [160]	valid_0's rmse: 0.966919
# [161]	valid_0's rmse: 0.966919
# [162]	valid_0's rmse: 0.966919
# [163]	valid_0's rmse: 0.966919
# [164]	valid_0's rmse: 0.966919
# [165]	valid_0's rmse: 0.966919
# [166]	valid_0's rmse: 0.966919
# [167]	valid_0's rmse: 0.966919
# [168]	valid_0's rmse: 0.966919
# [169]	valid_0's rmse: 0.966919
# [170]	valid_0's rmse: 0.966919
# [171]	valid_0's rmse: 0.966919
# [172]	valid_0's rmse: 0.966919
# [173]	valid_0's rmse: 0.966919
# [174]	valid_0's rmse: 0.966919
# [175]	valid_0's rmse: 0.966919
# [176]	valid_0's rmse: 0.966919
# [177]	valid_0's rmse: 0.966919
# [178]	valid_0's rmse: 0.966919
# [179]	valid_0's rmse: 0.966919
# [180]	valid_0's rmse: 0.966919
# [181]	valid_0's rmse: 0.966919
# [182]	valid_0's rmse: 0.966919
# [183]	valid_0's rmse: 0.966919
# [184]	valid_0's rmse: 0.966919
# [185]	valid_0's rmse: 0.966919
# [186]	valid_0's rmse: 0.966919
# [187]	valid_0's rmse: 0.966919
# [188]	valid_0's rmse: 0.966919
# [189]	valid_0's rmse: 0.966919
# [190]	valid_0's rmse: 0.966919
# [191]	valid_0's rmse: 0.966919
# [192]	valid_0's rmse: 0.966919
# [193]	valid_0's rmse: 0.966919
# [194]	valid_0's rmse: 0.966919
# [195]	valid_0's rmse: 0.966919
# [196]	valid_0's rmse: 0.966919
# Early stopping, best iteration is:
# [96]	valid_0's rmse: 0.966916
# 9
# [1]	valid_0's rmse: 1.06719
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 1.05574
# [3]	valid_0's rmse: 1.0443
# [4]	valid_0's rmse: 1.03457
# [5]	valid_0's rmse: 1.0256
# [6]	valid_0's rmse: 1.01877
# [7]	valid_0's rmse: 1.0131
# [8]	valid_0's rmse: 1.00813
# [9]	valid_0's rmse: 1.00447
# [10]	valid_0's rmse: 1.00077
# [11]	valid_0's rmse: 0.997379
# [12]	valid_0's rmse: 0.994536
# [13]	valid_0's rmse: 0.991705
# [14]	valid_0's rmse: 0.989211
# [15]	valid_0's rmse: 0.987093
# [16]	valid_0's rmse: 0.985186
# [17]	valid_0's rmse: 0.983726
# [18]	valid_0's rmse: 0.982038
# [19]	valid_0's rmse: 0.980636
# [20]	valid_0's rmse: 0.97943
# [21]	valid_0's rmse: 0.978194
# [22]	valid_0's rmse: 0.97719
# [23]	valid_0's rmse: 0.976257
# [24]	valid_0's rmse: 0.975407
# [25]	valid_0's rmse: 0.974625
# [26]	valid_0's rmse: 0.974166
# [27]	valid_0's rmse: 0.973443
# [28]	valid_0's rmse: 0.972829
# [29]	valid_0's rmse: 0.972177
# [30]	valid_0's rmse: 0.9717
# [31]	valid_0's rmse: 0.971108
# [32]	valid_0's rmse: 0.970777
# [33]	valid_0's rmse: 0.970488
# [34]	valid_0's rmse: 0.970173
# [35]	valid_0's rmse: 0.969947
# [36]	valid_0's rmse: 0.969698
# [37]	valid_0's rmse: 0.969498
# [38]	valid_0's rmse: 0.969252
# [39]	valid_0's rmse: 0.969054
# [40]	valid_0's rmse: 0.968758
# [41]	valid_0's rmse: 0.968368
# [42]	valid_0's rmse: 0.96829
# [43]	valid_0's rmse: 0.967991
# [44]	valid_0's rmse: 0.967782
# [45]	valid_0's rmse: 0.967619
# [46]	valid_0's rmse: 0.967507
# [47]	valid_0's rmse: 0.967295
# [48]	valid_0's rmse: 0.967155
# [49]	valid_0's rmse: 0.96691
# [50]	valid_0's rmse: 0.96679
# [51]	valid_0's rmse: 0.96668
# [52]	valid_0's rmse: 0.966574
# [53]	valid_0's rmse: 0.966491
# [54]	valid_0's rmse: 0.966332
# [55]	valid_0's rmse: 0.966283
# [56]	valid_0's rmse: 0.966197
# [57]	valid_0's rmse: 0.966103
# [58]	valid_0's rmse: 0.966011
# [59]	valid_0's rmse: 0.965928
# [60]	valid_0's rmse: 0.96584
# [61]	valid_0's rmse: 0.965809
# [62]	valid_0's rmse: 0.965775
# [63]	valid_0's rmse: 0.965732
# [64]	valid_0's rmse: 0.965617
# [65]	valid_0's rmse: 0.96556
# [66]	valid_0's rmse: 0.965525
# [67]	valid_0's rmse: 0.96545
# [68]	valid_0's rmse: 0.965386
# [69]	valid_0's rmse: 0.965355
# [70]	valid_0's rmse: 0.965295
# [71]	valid_0's rmse: 0.965278
# [72]	valid_0's rmse: 0.965252
# [73]	valid_0's rmse: 0.965238
# [74]	valid_0's rmse: 0.965183
# [75]	valid_0's rmse: 0.965169
# [76]	valid_0's rmse: 0.965145
# [77]	valid_0's rmse: 0.96511
# [78]	valid_0's rmse: 0.965097
# [79]	valid_0's rmse: 0.965067
# [80]	valid_0's rmse: 0.965029
# [81]	valid_0's rmse: 0.964985
# [82]	valid_0's rmse: 0.964915
# [83]	valid_0's rmse: 0.964874
# [84]	valid_0's rmse: 0.964867
# [85]	valid_0's rmse: 0.964848
# [86]	valid_0's rmse: 0.964831
# [87]	valid_0's rmse: 0.964792
# [88]	valid_0's rmse: 0.964782
# [89]	valid_0's rmse: 0.964763
# [90]	valid_0's rmse: 0.964761
# [91]	valid_0's rmse: 0.964732
# [92]	valid_0's rmse: 0.964729
# [93]	valid_0's rmse: 0.964712
# [94]	valid_0's rmse: 0.964695
# [95]	valid_0's rmse: 0.964692
# [96]	valid_0's rmse: 0.964687
# [97]	valid_0's rmse: 0.964687
# [98]	valid_0's rmse: 0.964677
# [99]	valid_0's rmse: 0.964667
# [100]	valid_0's rmse: 0.964665
# [101]	valid_0's rmse: 0.964654
# [102]	valid_0's rmse: 0.964639
# [103]	valid_0's rmse: 0.964617
# [104]	valid_0's rmse: 0.964613
# [105]	valid_0's rmse: 0.964613
# [106]	valid_0's rmse: 0.964613
# [107]	valid_0's rmse: 0.964613
# [108]	valid_0's rmse: 0.964613
# [109]	valid_0's rmse: 0.964613
# [110]	valid_0's rmse: 0.964616
# [111]	valid_0's rmse: 0.964616
# [112]	valid_0's rmse: 0.964616
# [113]	valid_0's rmse: 0.964616
# [114]	valid_0's rmse: 0.964616
# [115]	valid_0's rmse: 0.964616
# [116]	valid_0's rmse: 0.964616
# [117]	valid_0's rmse: 0.964616
# [118]	valid_0's rmse: 0.964616
# [119]	valid_0's rmse: 0.964616
# [120]	valid_0's rmse: 0.964616
# [121]	valid_0's rmse: 0.964616
# [122]	valid_0's rmse: 0.964616
# [123]	valid_0's rmse: 0.964616
# [124]	valid_0's rmse: 0.964616
# [125]	valid_0's rmse: 0.964616
# [126]	valid_0's rmse: 0.964616
# [127]	valid_0's rmse: 0.964616
# [128]	valid_0's rmse: 0.964616
# [129]	valid_0's rmse: 0.964616
# [130]	valid_0's rmse: 0.964616
# [131]	valid_0's rmse: 0.964616
# [132]	valid_0's rmse: 0.964616
# [133]	valid_0's rmse: 0.964616
# [134]	valid_0's rmse: 0.964616
# [135]	valid_0's rmse: 0.964616
# [136]	valid_0's rmse: 0.964616
# [137]	valid_0's rmse: 0.964616
# [138]	valid_0's rmse: 0.964616
# [139]	valid_0's rmse: 0.964616
# [140]	valid_0's rmse: 0.964616
# [141]	valid_0's rmse: 0.964616
# [142]	valid_0's rmse: 0.964616
# [143]	valid_0's rmse: 0.964616
# [144]	valid_0's rmse: 0.964616
# [145]	valid_0's rmse: 0.964616
# [146]	valid_0's rmse: 0.964616
# [147]	valid_0's rmse: 0.964616
# [148]	valid_0's rmse: 0.964616
# [149]	valid_0's rmse: 0.964616
# [150]	valid_0's rmse: 0.964616
# [151]	valid_0's rmse: 0.964616
# [152]	valid_0's rmse: 0.964616
# [153]	valid_0's rmse: 0.964616
# [154]	valid_0's rmse: 0.964616
# [155]	valid_0's rmse: 0.964616
# [156]	valid_0's rmse: 0.964616
# [157]	valid_0's rmse: 0.964616
# [158]	valid_0's rmse: 0.964616
# [159]	valid_0's rmse: 0.964616
# [160]	valid_0's rmse: 0.964616
# [161]	valid_0's rmse: 0.964616
# [162]	valid_0's rmse: 0.964616
# [163]	valid_0's rmse: 0.964616
# [164]	valid_0's rmse: 0.964616
# [165]	valid_0's rmse: 0.964616
# [166]	valid_0's rmse: 0.964616
# [167]	valid_0's rmse: 0.964616
# [168]	valid_0's rmse: 0.964616
# [169]	valid_0's rmse: 0.964616
# [170]	valid_0's rmse: 0.964616
# [171]	valid_0's rmse: 0.964616
# [172]	valid_0's rmse: 0.964616
# [173]	valid_0's rmse: 0.964616
# [174]	valid_0's rmse: 0.964616
# [175]	valid_0's rmse: 0.964616
# [176]	valid_0's rmse: 0.964616
# [177]	valid_0's rmse: 0.964616
# [178]	valid_0's rmse: 0.964616
# [179]	valid_0's rmse: 0.964616
# [180]	valid_0's rmse: 0.964616
# [181]	valid_0's rmse: 0.964616
# [182]	valid_0's rmse: 0.964616
# [183]	valid_0's rmse: 0.964616
# [184]	valid_0's rmse: 0.964616
# [185]	valid_0's rmse: 0.964616
# [186]	valid_0's rmse: 0.964616
# [187]	valid_0's rmse: 0.964616
# [188]	valid_0's rmse: 0.964616
# [189]	valid_0's rmse: 0.964616
# [190]	valid_0's rmse: 0.964616
# [191]	valid_0's rmse: 0.964616
# [192]	valid_0's rmse: 0.964616
# [193]	valid_0's rmse: 0.964616
# [194]	valid_0's rmse: 0.964616
# [195]	valid_0's rmse: 0.964616
# [196]	valid_0's rmse: 0.964616
# [197]	valid_0's rmse: 0.964616
# [198]	valid_0's rmse: 0.964616
# [199]	valid_0's rmse: 0.964616
# [200]	valid_0's rmse: 0.964616
# [201]	valid_0's rmse: 0.964616
# [202]	valid_0's rmse: 0.964616
# [203]	valid_0's rmse: 0.964616
# [204]	valid_0's rmse: 0.964616
# [205]	valid_0's rmse: 0.964616
# [206]	valid_0's rmse: 0.964616
# Early stopping, best iteration is:
# [106]	valid_0's rmse: 0.964613

# %%
all_predictions = np.stack(all_predictions,axis=1)
# all_training_predictions = np.stack(all_training_predictions,axis=1)

# %%
# trainX, testX, trainY, testY = train_test_split(all_training_predictions, Y, test_size=0.15)
# lgb_merging_model = lightgbm.LGBMRegressor(n_estimators=1000)
# lgb_merging_model.fit(
#         trainX,
#         trainY,
#         eval_set=(testX, testY),
#         eval_metric='rmse',
#         early_stopping_rounds=100,
#     )

# %%
final_predictions = all_predictions.mean(axis=1)

# %%
print(final_predictions.shape)
# Out:
# (146765,)

# %%
sample_submission['amount_spent_per_room_night_scaled'] = final_predictions
sample_submission.to_csv(
    "todu_fet2_lgb_tuning.csv",
    index=False)

# %%
trainX

# %%
d = pd.read_csv("/home/prashant/Downloads/481_47669_us_todu_fet2_lgb_tuning.csv")

# %%
d.head()
# Out:
#                                       reservation_id  \
# 0  7dae1ce6bc8f69481328f2be5c4943077dad5598b5f66d...
# 1  fe0d4e444e1818436c88f72f1cf800536c2f785e59baeb...
# 2  540bd4285ad8168e8388f84ee74a82cd4f97dc0a404d3e...
# 3  09593c907ae262e46f655b4db9e14f54a19eadcfdd2679...
# 4  f4c50caac68051faf37551d70bb17eebef2a20e2244cb1...
#
#    amount_spent_per_room_night_scaled
# 0                            8.160679
# 1                            7.389002
# 2                            7.475447
# 3                            7.861135
# 4                            7.895197

# %%
for ind, row in d.iterrows():
    if ind < 100:
        d.loc[ind, 'amount_spent_per_room_night_scaled'] = d.loc[ind, 'amount_spent_per_room_night_scaled'] + 1

# %%
d.head()
# Out:
#                                       reservation_id  \
# 0  7dae1ce6bc8f69481328f2be5c4943077dad5598b5f66d...
# 1  fe0d4e444e1818436c88f72f1cf800536c2f785e59baeb...
# 2  540bd4285ad8168e8388f84ee74a82cd4f97dc0a404d3e...
# 3  09593c907ae262e46f655b4db9e14f54a19eadcfdd2679...
# 4  f4c50caac68051faf37551d70bb17eebef2a20e2244cb1...
#
#    amount_spent_per_room_night_scaled
# 0                            9.160679
# 1                            8.389002
# 2                            8.475447
# 3                            8.861135
# 4                            8.895197

# %%
# %matplotlib inline

# %%
lightgbm.plot_importance(lgb_model,figsize=(20,30))

# %%
d.to_csv('testing_1.csv',index=False)
